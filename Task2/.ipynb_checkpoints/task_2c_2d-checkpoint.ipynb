# %% [markdown]
# # Task 2c

# %%
import torch
import os
import networkx as nx
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score
from scipy.stats import describe
import ncut
from itertools import product

# %% [markdown]
# ### Loading the graphs

# %%
def csv_to_graph(path, threshold=0.3):
    # load in csv as dataframe
    df = pd.read_csv(path,header=None)
    
    # threshold dataframe and remove diagonal
    A = (df>threshold).astype(int) - pd.DataFrame(np.identity(df.shape[0]))
         
    # convert to graph
    G = nx.from_pandas_adjacency(A)
    
    return G

def load_graphs(folder):
    #load in all graphs in folder
    G1s, G2s = [],[]

    for i in range(1,61):
        filename = f'{folder}/p{i:03}_1.csv'
        G1s.append(csv_to_graph(filename))

        filename = f'{folder}/p{i:03}_2.csv'
        G2s.append(csv_to_graph(filename))
        
    return G1s, G2s

G1s, G2s = load_graphs("FC")

# %%
def graph_list_to_multigraph(graphs):
    G = nx.MultiGraph()
    for subgraph in graphs:
        G.add_nodes_from(subgraph.nodes)
        G.add_edges_from(subgraph.edges)
    return G

# %%
G1 = graph_list_to_multigraph(G1s)
G2 = graph_list_to_multigraph(G2s)

# %% [markdown]
# ### Loading the embeddings

# %%
EMBEDDING_DIR = "embeddings"
G1_PATH = "best_G1_DMGI.pkl"
G2_PATH = "best_G2_DMGI.pkl"

# %%
EMBEDDING_DIR2 = "deepwalk_avg_embeddings"
G1_PATH2 = "G1.csv"
G2_PATH2 = "G2.csv"

# %%
g1_model = torch.load(os.path.join(EMBEDDING_DIR, G1_PATH))
g1_embedding = g1_model['H'].squeeze()

g2_model = torch.load(os.path.join(EMBEDDING_DIR, G2_PATH))
g2_embedding = g2_model['H'].squeeze()

# %%
g1_embedding2 = pd.read_csv(os.path.join(EMBEDDING_DIR2, G1_PATH2))
g2_embedding2 = pd.read_csv(os.path.join(EMBEDDING_DIR2, G2_PATH2))

# %% [markdown]
# ### Loading additional clinical data

# %%
clinical_csv = pd.read_csv("clinical.csv")
clinical_csv
# Out:
#       ID SEX                MS_TYPE  AGE  EDSS  DATASET  DIAG_YEARS     BMI  \
# 0   p001   M    primary_progressive   40     7        2          11  19.918
# 1   p002   M  secondary_progressive   44     7        2          17  20.529
# 2   p003   M    primary_progressive   51     6        2          21  25.249
# 3   p004   M    relapsing_remitting   29     3        2           9  21.500
# 4   p005   F  secondary_progressive   60     6        2          21  21.411
# 5   p006   M  secondary_progressive   68     4        2           7  21.605
# 6   p007   F    relapsing_remitting   36     4        2           9  19.370
# 7   p008   F    relapsing_remitting   32     4        2           4  19.141
# 8   p009   F    relapsing_remitting   35     4        1          20  16.436
# 9   p010   M  secondary_progressive   54     6        2          12  23.148
# 10  p011   M    relapsing_remitting   45     6        2          15  24.516
# 11  p012   M    relapsing_remitting   39     2        2          12  18.937
# 12  p013   F    relapsing_remitting   58     4        2          13  25.510
# 13  p014   M    primary_progressive   42     4        2           8  21.267
# 14  p015   F    relapsing_remitting   44     2        2          14  27.885
# 15  p016   M    relapsing_remitting   43     2        2          18  25.249
# 16  p017   M    relapsing_remitting   43     3        2          11  20.831
# 17  p018   F  secondary_progressive   53     5        2          17  35.380
# 18  p019   F  secondary_progressive   59     6        2          12  30.477
# 19  p020   F  secondary_progressive   58     4        2          19  20.833
# 20  p021   F  secondary_progressive   45     5        2          20  21.201
# 21  p022   M    relapsing_remitting   54     4        2          13  28.710
# 22  p023   M    primary_progressive   54     4        2           2  32.028
# 23  p024   F  secondary_progressive   38     5        2          17  22.656
# 24  p025   F  secondary_progressive   65     6        2          31  21.484
# 25  p026   M    relapsing_remitting   40     5        2          13  20.831
# 26  p027   F    relapsing_remitting   41     4        2           4  28.735
# 27  p028   F    relapsing_remitting   45     6        1           3  28.842
# 28  p029   F    relapsing_remitting   55     6        2          21  26.730
# 29  p030   M    relapsing_remitting   56     4        2           6  36.296
# 30  p031   F  secondary_progressive   56     5        2          14  21.755
# 31  p032   F    primary_progressive   59     4        2           4  26.573
# 32  p033   F    relapsing_remitting   39     5        1          15  18.145
# 33  p034   F    relapsing_remitting   22     1        1           1  21.107
# 34  p035   M  secondary_progressive   41     6        2           8  20.984
# 35  p036   F    relapsing_remitting   32     2        1           8  23.837
# 36  p037   M    relapsing_remitting   36     6        1          14  25.592
# 37  p038   F    relapsing_remitting   40     6        1          15  20.428
# 38  p039   F    relapsing_remitting   43     1        1          12  27.942
# 39  p040   F    relapsing_remitting   45     5        1          16  27.042
# 40  p041   F  secondary_progressive   35     5        1           8  21.830
# 41  p042   M    relapsing_remitting   40     2        1           9  19.818
# 42  p043   F    relapsing_remitting   50     3        1          10  22.137
# 43  p044   F  secondary_progressive   48     5        1          23  22.833
# 44  p045   M    relapsing_remitting   39     4        1          11  31.699
# 45  p046   F  secondary_progressive   63     4        1           3  23.809
# 46  p047   F  secondary_progressive   63     6        1          38  22.039
# 47  p048   F    relapsing_remitting   61     3        1          13  20.576
# 48  p049   F  secondary_progressive   58     4        1           4  33.802
# 49  p050   M    primary_progressive   53     1        1           1  24.057
# 50  p051   F  secondary_progressive   61     4        1           9  25.014
# 51  p052   M    relapsing_remitting   53     4        1           7  25.952
# 52  p053   F    relapsing_remitting   51     4        1          18  22.477
# 53  p054   M  secondary_progressive   63     6        1          22  21.701
# 54  p055   F  secondary_progressive   70     4        1          10  20.701
# 55  p056   F    relapsing_remitting   67     3        1          22  29.001
# 56  p057   M    relapsing_remitting   50     6        1          11  24.691
# 57  p058   F    relapsing_remitting   47     6        1          17  24.447
# 58  p059   F    relapsing_remitting   29     3        2           9  20.904
# 59  p060   F    relapsing_remitting   38     2        1          11  25.654
#
#                              THERAPY  outliers_V1  outliers_V2
# 0    Functional_electric_stimulation            0           14
# 1   Motor_Program_Activating_Therapy            4            0
# 2    Functional_electric_stimulation            4            0
# 3    Functional_electric_stimulation            4            2
# 4    Functional_electric_stimulation            0            4
# 5   Motor_Program_Activating_Therapy            2            3
# 6    Functional_electric_stimulation            6            7
# 7    Functional_electric_stimulation            5            7
# 8   Motor_Program_Activating_Therapy            3            0
# 9   Motor_Program_Activating_Therapy           20            6
# 10   Functional_electric_stimulation            0            2
# 11  Motor_Program_Activating_Therapy            0            2
# 12  Motor_Program_Activating_Therapy           38           13
# 13  Motor_Program_Activating_Therapy            0            3
# 14  Motor_Program_Activating_Therapy            4            0
# 15   Functional_electric_stimulation            0            6
# 16   Functional_electric_stimulation            0            0
# 17   Functional_electric_stimulation            2            4
# 18  Motor_Program_Activating_Therapy            4           42
# 19   Functional_electric_stimulation            0            2
# 20  Motor_Program_Activating_Therapy            0            0
# 21  Motor_Program_Activating_Therapy            0            0
# 22   Functional_electric_stimulation           19            6
# 23  Motor_Program_Activating_Therapy            0            0
# 24  Motor_Program_Activating_Therapy            0            0
# 25  Motor_Program_Activating_Therapy            0            0
# 26  Motor_Program_Activating_Therapy            0            0
# 27           Vojta_reflex_locomotion            0            2
# 28  Motor_Program_Activating_Therapy            0            0
# 29  Motor_Program_Activating_Therapy            4            9
# 30   Functional_electric_stimulation            0            2
# 31  Motor_Program_Activating_Therapy            0            5
# 32           Vojta_reflex_locomotion            4            0
# 33           Vojta_reflex_locomotion            0            0
# 34  Motor_Program_Activating_Therapy           10           25
# 35           Vojta_reflex_locomotion            0            0
# 36           Vojta_reflex_locomotion            0            5
# 37           Vojta_reflex_locomotion            2            2
# 38  Motor_Program_Activating_Therapy            2            0
# 39  Motor_Program_Activating_Therapy           10           30
# 40  Motor_Program_Activating_Therapy            4            6
# 41           Vojta_reflex_locomotion            0            0
# 42  Motor_Program_Activating_Therapy            4            2
# 43  Motor_Program_Activating_Therapy            2            4
# 44           Vojta_reflex_locomotion            2            4
# 45           Vojta_reflex_locomotion            3            9
# 46  Motor_Program_Activating_Therapy           41           21
# 47  Motor_Program_Activating_Therapy            0            0
# 48  Motor_Program_Activating_Therapy            4            2
# 49           Vojta_reflex_locomotion            0            2
# 50  Motor_Program_Activating_Therapy            8            3
# 51           Vojta_reflex_locomotion            6            3
# 52  Motor_Program_Activating_Therapy            0            5
# 53  Motor_Program_Activating_Therapy            8            0
# 54  Motor_Program_Activating_Therapy            5            0
# 55  Motor_Program_Activating_Therapy            2           14
# 56           Vojta_reflex_locomotion            0            0
# 57  Motor_Program_Activating_Therapy            0            0
# 58  Motor_Program_Activating_Therapy            0            0
# 59           Vojta_reflex_locomotion            0            0

# %% [markdown]
# ## Validation of our NCut implementation
# We validate our implementation of NCut against networkx by comparing the NCut values of random graph partitions. The reason for restricting ourselves to binary partitions is that the networkx function normalized_cut_size is only applicable to binary partitions.

# %%
# binary partitions validation on multigraphs

identical = True
graphs = [G1, G2]

n_checks = 10
precision = 1e-10

for i in range(n_checks):

        print(f"Checking random partition no. {i}")
        clustering = np.random.randint(0, 2, size=len(G1.nodes))
        
        nodes1 = np.where(clustering==0)[0]
        nodes2 = np.where(clustering==1)[0]

        for graph in graphs:
            nx_result = nx.normalized_cut_size(graph, nodes1, nodes2)
            our_result = ncut.ncut_multigraph(graph, nodes1, nodes2)
            our_k_result = ncut.k_ncut_multigraph(graph, np.asarray([nodes1, nodes2], dtype=object))
            
            if abs(our_result - nx_result) > precision or abs(our_k_result - nx_result) > precision:
                identical = False
                break
        
        else:
            continue
        
        break

print(f"\nOur results were{' ' if identical else ' not '}identical to those of networkx for {n_checks} random partitions.")
# Out:
# Checking random partition no. 0
# Checking random partition no. 1
# Checking random partition no. 2
# Checking random partition no. 3
# Checking random partition no. 4
# Checking random partition no. 5
# Checking random partition no. 6
# Checking random partition no. 7
# Checking random partition no. 8
# Checking random partition no. 9
#
# Our results were identical to those of networkx for 10 random partitions.

# %% [markdown]
# After validating our NCut implementation on multigraphs, we do the same for the individual patient graphs.

# %%
# binary partitions validation on single graphs

identical = True
graphs = [G1s, G2s]

n_checks = 10
precision = 1e-10

for i in range(n_checks):
    
        print(f"Checking random partition no. {i}")
        clustering = np.random.randint(0, 2, size=len(G1.nodes))
        
        for graph in graphs:
            for subgraph in graph:

                nodes1 = np.where(clustering==0)[0]
                nodes2 = np.where(clustering==1)[0]

                nx_result = nx.normalized_cut_size(subgraph, nodes1, nodes2)
                our_result = ncut.ncut_multigraph(subgraph, nodes1, nodes2)
                our_k_result = ncut.k_ncut_multigraph(subgraph, np.asarray([nodes1, nodes2], dtype=object))

                if abs(our_result - nx_result) > precision or \
                    abs(our_k_result - nx_result) > precision or \
                    abs(our_result - nx_result) > precision:
                        
                    identical = False
                    break
        
        else:
            continue
        
        break

print(f"\nOur results were{' ' if identical else ' not '}identical to those of networkx for {n_checks} random partitions.")
# Out:
# Checking random partition no. 0
# Checking random partition no. 1
# Checking random partition no. 2
# Checking random partition no. 3
# Checking random partition no. 4
# Checking random partition no. 5
# Checking random partition no. 6
# Checking random partition no. 7
# Checking random partition no. 8
# Checking random partition no. 9
#
# Our results were identical to those of networkx for 10 random partitions.

# %% [markdown]
# ## Clustering the data
# We cluster the embeddings with KMeans with different cluster values (i.e. the n_clusters parameter) between 2 and 20 and compare the results with the NCut value. To find out the NCut value of more than two partitions, we implement the k_NCut value, which is an extension of the NCut for two partitions. When comparing different cluster values, it seems that higher cluster values always lead to higher NCut values. This seems intuitive, as a higher cluster value means that there are more edges between clusters rather than within clusters. \
# \
# When we try to use the k_Ncut value to compare the clusterings, it appears that the best cluster value is 2, since it has the lowest amount of inter-cluster connectivity divided by intra-cluster connectivity.

# %%
def ncut_by_k_partition(graph, partition):
    """Helper function to generate the right input structure for ncut.k_ncut_multigraph"""
    node_lists = np.asarray([np.where(partition == value)[0] for value in np.unique(partition)], dtype=object)
    return ncut.k_ncut_multigraph(graph, node_lists)

# %% [markdown]
# ### DMGI embeddings
# For all cluster values, it seems that the NCut results are slightly lower for the second graph: This is surprising, as we expect the patients' functional connectivity between different brain regions to be increased after the intervention, while the NCut-value seems to show the opposite. However, it needs to be noted that the clusterings are not identical between the two graphs (for a comparison, see the section about NMIs) and this might also play a role.

# %%
n_clusters = range(2, 20)

kmeans_ncut_results = []

for n in n_clusters:
    kmeans = KMeans(n_clusters=n, n_init=10)
    clustering1 = kmeans.fit_predict(g1_embedding)
    clustering2 = kmeans.fit_predict(g2_embedding)
    g1_ncut = ncut_by_k_partition(G1, clustering1)
    g2_ncut = ncut_by_k_partition(G2, clustering2)
    kmeans_ncut_results.append((f"KMeans n_clusters={n}", g1_ncut, g2_ncut, clustering1, clustering2))

# %%
for result in kmeans_ncut_results:
    print(result[:3])
# Out:
# ('KMeans n_clusters=2', 1.024880406778286, 0.6495013698487705)
# ('KMeans n_clusters=3', 1.9580156474352046, 1.519939476871253)
# ('KMeans n_clusters=4', 3.0065981141918745, 2.5559301316819623)
# ('KMeans n_clusters=5', 4.018580585153811, 3.638231279504795)
# ('KMeans n_clusters=6', 4.9847158876454865, 4.620613493407045)
# ('KMeans n_clusters=7', 6.058132478190282, 5.654989180923791)
# ('KMeans n_clusters=8', 7.065467506137667, 6.733883586836054)
# ('KMeans n_clusters=9', 8.05968786144697, 7.7965225017960345)
# ('KMeans n_clusters=10', 9.022788650045973, 8.661385107042365)
# ('KMeans n_clusters=11', 10.065214524559195, 9.849303608131923)
# ('KMeans n_clusters=12', 10.997347383376189, 10.782902996043434)
# ('KMeans n_clusters=13', 12.039823455419073, 11.708529314413722)
# ('KMeans n_clusters=14', 12.983167324670026, 12.833004467458428)
# ('KMeans n_clusters=15', 14.104219928117955, 13.884194788011358)
# ('KMeans n_clusters=16', 15.086816569062066, 14.802082457710556)
# ('KMeans n_clusters=17', 16.02026035255005, 15.775685504627246)
# ('KMeans n_clusters=18', 17.13742947705443, 16.775966215757467)
# ('KMeans n_clusters=19', 17.9845774657421, 17.988297634046237)

# %% [markdown]
# #### Hemisphere cluster correspondence

# %% [markdown]
# For the binary clustering, we checked whether the clusters correspond to the hemispheres in the brain. As stated in the file AAL_labels.csv, odd indices correspond to left hempishere region and even indices to right hemisphere regions, apart from the Cerebellar Vermis. It appears that there is no connection between the cluster labels and the hemisphere for the first graph, but for the second graph, about 75% of the left hemisphere belongs to cluster 2 and about 75% of the right hemisphere to cluster 1. The cerebellar vermis was assigned to cluster 1 in its entirety. In conclusion, it seems that the information stored in the DMGI embedding allows us to find a connection between the brain hemisphere and functional connectivity after the treatment.

# %%
clustering_DMGI_G1 = kmeans_ncut_results[0][3]

even_indices = clustering_DMGI_G1[:108:2]
print(f"Fraction of the left hemisphere which belongs to cluster 1: {sum(even_indices==0)/len(even_indices)}")
print(f"Fraction of the left hemisphere which belongs to cluster 2: {sum(even_indices==1)/len(even_indices)}")
print()

odd_indices =  clustering_DMGI_G1[1:108:2]
print(f"Fraction of the right hemisphere which belongs to cluster 1: {sum(odd_indices==0)/len(odd_indices)}")
print(f"Fraction of the right hemisphere which belongs to cluster 2: {sum(odd_indices==1)/len(odd_indices)}")

print()

cerebellum_indices = clustering_DMGI_G1[108::]
print(f"Fraction of the cerebellar vermis which belongs to cluster 1: {sum(cerebellum_indices==0)/len(cerebellum_indices)}")
print(f"Fraction of the cerebellar vermis which belongs to cluster 2: {sum(cerebellum_indices==1)/len(cerebellum_indices)}")
# Out:
# Fraction of the left hemisphere which belongs to cluster 1: 0.5370370370370371
# Fraction of the left hemisphere which belongs to cluster 2: 0.46296296296296297
#
# Fraction of the right hemisphere which belongs to cluster 1: 0.4074074074074074
# Fraction of the right hemisphere which belongs to cluster 2: 0.5925925925925926
#
# Fraction of the cerebellar vermis which belongs to cluster 1: 0.25
# Fraction of the cerebellar vermis which belongs to cluster 2: 0.75

# %%
clustering_DMGI_G2 = kmeans_ncut_results[0][4]

even_indices = clustering_DMGI_G2[:108:2]
print(f"Fraction of the left hemisphere which belongs to cluster 1: {sum(even_indices==0)/len(even_indices)}")
print(f"Fraction of the left hemisphere which belongs to cluster 2: {sum(even_indices==1)/len(even_indices)}")
print()

odd_indices =  clustering_DMGI_G2[1:108:2]
print(f"Fraction of the right hemisphere which belongs to cluster 1: {sum(odd_indices==0)/len(odd_indices)}")
print(f"Fraction of the right hemisphere which belongs to cluster 2: {sum(odd_indices==1)/len(odd_indices)}")

print()

cerebellum_indices = clustering_DMGI_G2[108::]
print(f"Fraction of the cerebellar vermis which belongs to cluster 1: {sum(cerebellum_indices==0)/len(cerebellum_indices)}")
print(f"Fraction of the cerebellar vermis which belongs to cluster 2: {sum(cerebellum_indices==1)/len(cerebellum_indices)}")
# Out:
# Fraction of the left hemisphere which belongs to cluster 1: 0.25925925925925924
# Fraction of the left hemisphere which belongs to cluster 2: 0.7407407407407407
#
# Fraction of the right hemisphere which belongs to cluster 1: 0.2777777777777778
# Fraction of the right hemisphere which belongs to cluster 2: 0.7222222222222222
#
# Fraction of the cerebellar vermis which belongs to cluster 1: 1.0
# Fraction of the cerebellar vermis which belongs to cluster 2: 0.0

# %% [markdown]
# ### Deepwalk_embeddings

# %%
kmeans_ncut_results2 = []

for n in n_clusters:
    kmeans = KMeans(n_clusters=n, n_init=10)
    clustering1 = kmeans.fit_predict(g1_embedding2)
    clustering2 = kmeans.fit_predict(g2_embedding2)
    g1_ncut = ncut_by_k_partition(G1, clustering1)
    g2_ncut = ncut_by_k_partition(G2, clustering2)
    kmeans_ncut_results2.append((f"KMeans n_clusters={n}", g1_ncut, g2_ncut, clustering1, clustering2))

# %%
for result in kmeans_ncut_results2:
    print(result[:3])
# Out:
# ('KMeans n_clusters=2', 0.820246617737858, 0.8042759676805062)
# ('KMeans n_clusters=3', 1.4400629044966995, 1.4092902004836843)
# ('KMeans n_clusters=4', 2.1516882610944132, 2.0835758753989575)
# ('KMeans n_clusters=5', 3.0348326614164005, 3.0312564616456927)
# ('KMeans n_clusters=6', 3.8418771331593153, 3.8648791537045035)
# ('KMeans n_clusters=7', 4.788028739182342, 4.751821079418336)
# ('KMeans n_clusters=8', 5.56942732852477, 5.586115166186394)
# ('KMeans n_clusters=9', 6.559653012549149, 6.598872719793632)
# ('KMeans n_clusters=10', 7.663557774351519, 7.3516615096505955)
# ('KMeans n_clusters=11', 8.415235710964383, 8.355696514443885)
# ('KMeans n_clusters=12', 9.443606057812932, 9.102016119018064)
# ('KMeans n_clusters=13', 10.218559154096031, 10.170828701315088)
# ('KMeans n_clusters=14', 11.21989353405305, 11.116672962094908)
# ('KMeans n_clusters=15', 12.071271051457352, 11.642394123267648)
# ('KMeans n_clusters=16', 13.072848983417073, 12.625045383503572)
# ('KMeans n_clusters=17', 14.051196777159518, 13.937624182370953)
# ('KMeans n_clusters=18', 15.156846627621928, 14.620412287964966)
# ('KMeans n_clusters=19', 15.800988272267187, 15.978729374790927)

# %% [markdown]
# #### Hemisphere cluster correspondence
# It appears that there is no consistent correspondence between the cluster labels and the hemispheres for the deepwalk embeddings. Since the clusterings are identical for n_clusters=2 (see the NMI section), the hemisphere/cluster correspendences are also identical for the two graphs.

# %%
clustering_deepwalk_G1 = kmeans_ncut_results2[0][3]

even_indices = clustering_deepwalk_G1[:108:2]
print(f"Fraction of the left hemisphere which belongs to cluster 1: {sum(even_indices==0)/len(even_indices)}")
print(f"Fraction of the left hemisphere which belongs to cluster 2: {sum(even_indices==1)/len(even_indices)}")
print()

odd_indices =  clustering_deepwalk_G1[1:108:2]
print(f"Fraction of the right hemisphere which belongs to cluster 1: {sum(odd_indices==0)/len(odd_indices)}")
print(f"Fraction of the right hemisphere which belongs to cluster 2: {sum(odd_indices==1)/len(odd_indices)}")

print()

cerebellum_indices = clustering_deepwalk_G1[108::]
print(f"Fraction of the cerebellar vermis which belongs to cluster 1: {sum(cerebellum_indices==0)/len(cerebellum_indices)}")
print(f"Fraction of the cerebellar vermis which belongs to cluster 2: {sum(cerebellum_indices==1)/len(cerebellum_indices)}")
# Out:
# Fraction of the left hemisphere which belongs to cluster 1: 0.46296296296296297
# Fraction of the left hemisphere which belongs to cluster 2: 0.5370370370370371
#
# Fraction of the right hemisphere which belongs to cluster 1: 0.46296296296296297
# Fraction of the right hemisphere which belongs to cluster 2: 0.5370370370370371
#
# Fraction of the cerebellar vermis which belongs to cluster 1: 1.0
# Fraction of the cerebellar vermis which belongs to cluster 2: 0.0

# %%
clustering_deepwalk_G2 = kmeans_ncut_results2[0][4]

even_indices = clustering_deepwalk_G2[:108:2]
print(f"Fraction of the left hemisphere which belongs to cluster 1: {sum(even_indices==0)/len(even_indices)}")
print(f"Fraction of the left hemisphere which belongs to cluster 2: {sum(even_indices==1)/len(even_indices)}")
print()

odd_indices =  clustering_deepwalk_G2[1:108:2]
print(f"Fraction of the right hemisphere which belongs to cluster 1: {sum(odd_indices==0)/len(odd_indices)}")
print(f"Fraction of the right hemisphere which belongs to cluster 2: {sum(odd_indices==1)/len(odd_indices)}")

print()

cerebellum_indices = clustering_deepwalk_G2[108::]
print(f"Fraction of the cerebellar vermis which belongs to cluster 1: {sum(cerebellum_indices==0)/len(cerebellum_indices)}")
print(f"Fraction of the cerebellar vermis which belongs to cluster 2: {sum(cerebellum_indices==1)/len(cerebellum_indices)}")
# Out:
# Fraction of the left hemisphere which belongs to cluster 1: 0.46296296296296297
# Fraction of the left hemisphere which belongs to cluster 2: 0.5370370370370371
#
# Fraction of the right hemisphere which belongs to cluster 1: 0.46296296296296297
# Fraction of the right hemisphere which belongs to cluster 2: 0.5370370370370371
#
# Fraction of the cerebellar vermis which belongs to cluster 1: 1.0
# Fraction of the cerebellar vermis which belongs to cluster 2: 0.0

# %% [markdown]
# ## Comparison of partitions

# %% [markdown]
# ### Comparison of NCut-values
# For both embeddings, the NCut-values of the clusterings are slightly higher for the first graph.

# %%
# DMGI emebeddings
kmeans_ncut_results = [list(res) for res in kmeans_ncut_results]
result_diffs = np.asarray([res[1] - res[2] for res in kmeans_ncut_results])
describe(result_diffs)
# Out:
# DescribeResult(nobs=18, minmax=(-0.0037201683041381273, 0.45066798250991225), mean=0.29926447241467735, variance=0.012841906122102656, skewness=-0.9969422040326614, kurtosis=0.8565042692840699)

# %%
# Deepwalk embeddings
kmeans_ncut_results2 = [list(res) for res in kmeans_ncut_results2]
result_diffs = np.asarray([res[1] - res[2] for res in kmeans_ncut_results2])
describe(result_diffs)
# Out:
# DescribeResult(nobs=18, minmax=(-0.17774110252373987, 0.536434339656962), mean=0.12714737881275595, variance=0.03915712589689944, skewness=0.780559951787912, kurtosis=-0.5156534503959724)

# %% [markdown]
# ### NMI scores
# We calculate the normalized mutual information scores of out clustering results to find how similar the KMeans clusterings are in first compared to the second graph. The DMGI embedding clusterings are very different from each other but become more similar as the number of clusters increases. The opposite effect occurs for the deepwalk embeddings, where the NMI scores rise with the number of clusters, but the deepwalk clusterings are very similar in general.

# %%
# DMGI embeddings
descriptions = [res[0] for res in kmeans_ncut_results]

kmeans_nmis = [normalized_mutual_info_score(res[3], res[4]) for res in kmeans_ncut_results]
for res, nmi in zip(descriptions, kmeans_nmis):
    print(f"{res} NMI: {nmi}")
# Out:
# KMeans n_clusters=2 NMI: 9.422748854569653e-06
# KMeans n_clusters=3 NMI: 0.032391744409827526
# KMeans n_clusters=4 NMI: 0.19481148712949176
# KMeans n_clusters=5 NMI: 0.109158657088973
# KMeans n_clusters=6 NMI: 0.14491995785596387
# KMeans n_clusters=7 NMI: 0.21118830546009346
# KMeans n_clusters=8 NMI: 0.17900473981915177
# KMeans n_clusters=9 NMI: 0.24402673833914307
# KMeans n_clusters=10 NMI: 0.28194824170958543
# KMeans n_clusters=11 NMI: 0.3034865423877481
# KMeans n_clusters=12 NMI: 0.3177710082020356
# KMeans n_clusters=13 NMI: 0.2943245095235929
# KMeans n_clusters=14 NMI: 0.37885843121235946
# KMeans n_clusters=15 NMI: 0.35268584261404695
# KMeans n_clusters=16 NMI: 0.5102443308185651
# KMeans n_clusters=17 NMI: 0.4075450237562027
# KMeans n_clusters=18 NMI: 0.45681089097247274
# KMeans n_clusters=19 NMI: 0.47815599222348676

# %%
# Deepwalk embeddings
descriptions = [res[0] for res in kmeans_ncut_results2]

kmeans_nmis = [normalized_mutual_info_score(res[3], res[4]) for res in kmeans_ncut_results2]
for res, nmi in zip(descriptions, kmeans_nmis):
    print(f"{res} NMI: {nmi}")
# Out:
# KMeans n_clusters=2 NMI: 1.0
# KMeans n_clusters=3 NMI: 0.9014884656713177
# KMeans n_clusters=4 NMI: 0.9727300607485628
# KMeans n_clusters=5 NMI: 0.9192781466225672
# KMeans n_clusters=6 NMI: 0.8205210633900838
# KMeans n_clusters=7 NMI: 0.7935904350274092
# KMeans n_clusters=8 NMI: 0.8687171305710435
# KMeans n_clusters=9 NMI: 0.8393766982496269
# KMeans n_clusters=10 NMI: 0.7859333826730857
# KMeans n_clusters=11 NMI: 0.8570674608083465
# KMeans n_clusters=12 NMI: 0.8314009475854333
# KMeans n_clusters=13 NMI: 0.829817107193702
# KMeans n_clusters=14 NMI: 0.7849568476940962
# KMeans n_clusters=15 NMI: 0.8361091882621564
# KMeans n_clusters=16 NMI: 0.8493950213814582
# KMeans n_clusters=17 NMI: 0.790304392695595
# KMeans n_clusters=18 NMI: 0.8325079369991409
# KMeans n_clusters=19 NMI: 0.8268504636781306

# %% [markdown]
# ### Comparison by attributes in clinical.csv
# In this section we investigate whether the attributes in clinical.csv (such as the age) have an influence on the NCut values of the partitions. To do that, we interpret the column values of clinical.csv as cluster labels, and compute the NCut values of the graph layers (i.e. the patients) individually. Afterwards, we group the NCut values by cluster labels and compare descriptive statistics between the groups.

# %%
comparison_attributes = [
    ['sex', clinical_csv['SEX']],
    ['age over 50', clinical_csv['AGE'] > 50],
    ['BMI over 25', clinical_csv['BMI'] > 25],
    ['MS type', clinical_csv['MS_TYPE']],
    ['therapy', clinical_csv['THERAPY']]
]

# %% [markdown]
# #### DMGI Embeddings

# %%
# takes a while to run

individual_ncuts = []

for res in kmeans_ncut_results:
    
    G1_ncuts = []
    G1_partition = res[3]
    for patient in G1s:
        G1_ncuts.append(ncut_by_k_partition(patient, G1_partition))

    G2_ncuts = []
    G2_partition = res[4]
    for patient in G2s:
        G2_ncuts.append(ncut_by_k_partition(patient, G2_partition))
        
    individual_ncuts.append([res[0], G1_ncuts, G2_ncuts])

# %%
attribute_statistics = []

for part_description, G1_ncuts, G2_ncuts in individual_ncuts:
    for comp_description, labels in comparison_attributes:
        
        label_ncuts_g1 = {}
        label_ncuts_g2 = {}
        
        for label in np.unique(labels):
            indices = np.where(labels == label)[0]
            
            # note: if desired, more descriptive statistics could be saved here
            stats = describe(np.asarray(G1_ncuts)[indices])
            label_ncuts_g1[label] = {'mean': stats.mean, 'variance': stats.variance}
            
            stats = describe(np.asarray(G2_ncuts)[indices])
            label_ncuts_g2[label] = {'mean': stats.mean, 'variance': stats.variance}
            
        attribute_statistics.append({'partition_name' : part_description, 'attribute_name' : comp_description,
                                    'G1' : label_ncuts_g1, 'G2' : label_ncuts_g2})

# %%
for entry in attribute_statistics:
    
    print("Partition:", entry['partition_name'])
    print("Attribute:", entry['attribute_name'], "\n")
    
    for key in entry['G1'].keys():
        print(key)
        print("G1 mean ncut:", entry['G1'][key]['mean'])
        print("G2 mean ncut:", entry['G2'][key]['mean'])
        print()
        
    print("-------------------")
# Out:
# Partition: KMeans n_clusters=2
# Attribute: sex
#
# F
# G1 mean ncut: 1.0257011217250185
# G2 mean ncut: 0.6628454753436009
#
# M
# G1 mean ncut: 1.0241832793645904
# G2 mean ncut: 0.6294301691180958
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: age over 50
#
# False
# G1 mean ncut: 1.0282448260194192
# G2 mean ncut: 0.6464230503297234
#
# True
# G1 mean ncut: 1.0210320324827311
# G2 mean ncut: 0.6547612602391861
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 1.0240270117339338
# G2 mean ncut: 0.6535553762916585
#
# True
# G1 mean ncut: 1.027005931060081
# G2 mean ncut: 0.6439578262884734
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 1.0245643917606044
# G2 mean ncut: 0.607378169681908
#
# relapsing_remitting
# G1 mean ncut: 1.0254146902517212
# G2 mean ncut: 0.6533056111954246
#
# secondary_progressive
# G1 mean ncut: 1.0247835555044555
# G2 mean ncut: 0.6572758339346775
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 1.0212199636260935
# G2 mean ncut: 0.6550210155805165
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 1.0285957693774292
# G2 mean ncut: 0.6474543800458068
#
# Vojta_reflex_locomotion
# G1 mean ncut: 1.019926249479958
# G2 mean ncut: 0.6518041810250224
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: sex
#
# F
# G1 mean ncut: 1.9599184161946097
# G2 mean ncut: 1.5281207951521978
#
# M
# G1 mean ncut: 1.9586052941898349
# G2 mean ncut: 1.5033930306692616
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: age over 50
#
# False
# G1 mean ncut: 1.9657686504361873
# G2 mean ncut: 1.527505168732428
#
# True
# G1 mean ncut: 1.9511065019514002
# G2 mean ncut: 1.5070512841969916
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 1.9603746768566468
# G2 mean ncut: 1.5168132476259233
#
# True
# G1 mean ncut: 1.9577575202279183
# G2 mean ncut: 1.5218002598290565
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 1.9710683638232378
# G2 mean ncut: 1.495878644058954
#
# relapsing_remitting
# G1 mean ncut: 1.961348787824698
# G2 mean ncut: 1.520559537717077
#
# secondary_progressive
# G1 mean ncut: 1.9526317098293806
# G2 mean ncut: 1.5222106489644993
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 1.9668346170676059
# G2 mean ncut: 1.518503689599791
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 1.9541391325870863
# G2 mean ncut: 1.532986048269016
#
# Vojta_reflex_locomotion
# G1 mean ncut: 1.9657940489020738
# G2 mean ncut: 1.481264270775423
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: sex
#
# F
# G1 mean ncut: 3.006090761149192
# G2 mean ncut: 2.5590750843334056
#
# M
# G1 mean ncut: 3.0174041316901103
# G2 mean ncut: 2.5504234449134136
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: age over 50
#
# False
# G1 mean ncut: 3.008399355306484
# G2 mean ncut: 2.5708507764216897
#
# True
# G1 mean ncut: 3.013079811960469
# G2 mean ncut: 2.536022729038734
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 3.012548161180146
# G2 mean ncut: 2.5607645091824343
#
# True
# G1 mean ncut: 3.0067646848430503
# G2 mean ncut: 2.547112091109638
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 2.9993805550942625
# G2 mean ncut: 2.511756933842869
#
# relapsing_remitting
# G1 mean ncut: 3.009900245008233
# G2 mean ncut: 2.560472789080158
#
# secondary_progressive
# G1 mean ncut: 3.0146380765273593
# G2 mean ncut: 2.560945046078097
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 3.0084478536872057
# G2 mean ncut: 2.549702422878624
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 3.0087853227808345
# G2 mean ncut: 2.5682533811734642
#
# Vojta_reflex_locomotion
# G1 mean ncut: 3.016702316839277
# G2 mean ncut: 2.5291362227711267
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: sex
#
# F
# G1 mean ncut: 4.024527859307898
# G2 mean ncut: 3.64795723818841
#
# M
# G1 mean ncut: 4.010304390375371
# G2 mean ncut: 3.621520979584507
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: age over 50
#
# False
# G1 mean ncut: 4.019515908465795
# G2 mean ncut: 3.626538502780274
#
# True
# G1 mean ncut: 4.018499649430337
# G2 mean ncut: 3.652580432649443
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 4.016024959504268
# G2 mean ncut: 3.637452712895257
#
# True
# G1 mean ncut: 4.024344695993799
# G2 mean ncut: 3.6384635115179553
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 4.0099887743864135
# G2 mean ncut: 3.6114765440752445
#
# relapsing_remitting
# G1 mean ncut: 4.020252661680068
# G2 mean ncut: 3.6393444195885927
#
# secondary_progressive
# G1 mean ncut: 4.019800431479245
# G2 mean ncut: 3.6431415406475587
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 4.0204394057825645
# G2 mean ncut: 3.6397054337468147
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 4.019144940860624
# G2 mean ncut: 3.6398153964325686
#
# Vojta_reflex_locomotion
# G1 mean ncut: 4.017530116045477
# G2 mean ncut: 3.63073124815376
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: sex
#
# F
# G1 mean ncut: 4.988042472663089
# G2 mean ncut: 4.639025668099596
#
# M
# G1 mean ncut: 4.988146903349088
# G2 mean ncut: 4.5891023070525305
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: age over 50
#
# False
# G1 mean ncut: 4.983680468023908
# G2 mean ncut: 4.628793085150147
#
# True
# G1 mean ncut: 4.9938390135673245
# G2 mean ncut: 4.6082437648764705
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 4.9840693694052165
# G2 mean ncut: 4.6333170752502575
#
# True
# G1 mean ncut: 4.9950142830984126
# G2 mean ncut: 4.596693360108338
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 5.007033658816186
# G2 mean ncut: 4.599097581184733
#
# relapsing_remitting
# G1 mean ncut: 4.985575546259772
# G2 mean ncut: 4.614305847082776
#
# secondary_progressive
# G1 mean ncut: 4.986658986991695
# G2 mean ncut: 4.635615924698523
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 4.998045628101429
# G2 mean ncut: 4.632757112862723
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 4.985881050503615
# G2 mean ncut: 4.620175139454942
#
# Vojta_reflex_locomotion
# G1 mean ncut: 4.983877029470909
# G2 mean ncut: 4.606269659477676
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: sex
#
# F
# G1 mean ncut: 6.062673971129899
# G2 mean ncut: 5.657240515462768
#
# M
# G1 mean ncut: 6.071843976929033
# G2 mean ncut: 5.655051309196157
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: age over 50
#
# False
# G1 mean ncut: 6.0809201953845395
# G2 mean ncut: 5.650921947044519
#
# True
# G1 mean ncut: 6.046925452234604
# G2 mean ncut: 5.663566653235401
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 6.07139290611052
# G2 mean ncut: 5.65173056372842
#
# True
# G1 mean ncut: 6.057200816771559
# G2 mean ncut: 5.664468989179732
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 6.084229036901302
# G2 mean ncut: 5.655379262404558
#
# relapsing_remitting
# G1 mean ncut: 6.073983692575532
# G2 mean ncut: 5.651880327421087
#
# secondary_progressive
# G1 mean ncut: 6.047526431609905
# G2 mean ncut: 5.664393623844487
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 6.099623567676437
# G2 mean ncut: 5.671749189344992
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 6.0508646411870375
# G2 mean ncut: 5.669513427989251
#
# Vojta_reflex_locomotion
# G1 mean ncut: 6.072834170847774
# G2 mean ncut: 5.60676024388574
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: sex
#
# F
# G1 mean ncut: 7.068354917264373
# G2 mean ncut: 6.751090962286376
#
# M
# G1 mean ncut: 7.081548796080581
# G2 mean ncut: 6.726529106413955
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: age over 50
#
# False
# G1 mean ncut: 7.06567210398752
# G2 mean ncut: 6.737917600582987
#
# True
# G1 mean ncut: 7.083534719733054
# G2 mean ncut: 6.7465898704728975
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 7.067475869392854
# G2 mean ncut: 6.740146761131568
#
# True
# G1 mean ncut: 7.083666873259395
# G2 mean ncut: 6.744316278596243
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 7.122991067008371
# G2 mean ncut: 6.67965638599961
#
# relapsing_remitting
# G1 mean ncut: 7.070123768262894
# G2 mean ncut: 6.741865082647255
#
# secondary_progressive
# G1 mean ncut: 7.064129986282325
# G2 mean ncut: 6.75995919630563
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 7.099892736024399
# G2 mean ncut: 6.728855480806062
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 7.066865014990084
# G2 mean ncut: 6.7484612344323045
#
# Vojta_reflex_locomotion
# G1 mean ncut: 7.064056782358084
# G2 mean ncut: 6.73674860237998
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: sex
#
# F
# G1 mean ncut: 8.06320489545461
# G2 mean ncut: 7.803920697480114
#
# M
# G1 mean ncut: 8.051250303684089
# G2 mean ncut: 7.7818554517721665
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: age over 50
#
# False
# G1 mean ncut: 8.066796818381864
# G2 mean ncut: 7.78324722193246
#
# True
# G1 mean ncut: 8.047932549675815
# G2 mean ncut: 7.811435986608479
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 8.067935256783068
# G2 mean ncut: 7.782889277517674
#
# True
# G1 mean ncut: 8.042536289036276
# G2 mean ncut: 7.817179484175114
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 8.069266110642356
# G2 mean ncut: 7.8001284158315025
#
# relapsing_remitting
# G1 mean ncut: 8.053543277447474
# G2 mean ncut: 7.791201720142497
#
# secondary_progressive
# G1 mean ncut: 8.064063500974319
# G2 mean ncut: 7.801305610884509
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 8.08202541841454
# G2 mean ncut: 7.817105628864795
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 8.0410128595395
# G2 mean ncut: 7.7952718105778125
#
# Vojta_reflex_locomotion
# G1 mean ncut: 8.081274650217122
# G2 mean ncut: 7.774317420202776
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: sex
#
# F
# G1 mean ncut: 9.024841899161592
# G2 mean ncut: 8.678196146851418
#
# M
# G1 mean ncut: 9.035716509613813
# G2 mean ncut: 8.647106469888728
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: age over 50
#
# False
# G1 mean ncut: 9.026041609000188
# G2 mean ncut: 8.659792810956176
#
# True
# G1 mean ncut: 9.032892895541933
# G2 mean ncut: 8.674759641093583
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 9.02591451311145
# G2 mean ncut: 8.65707953492517
#
# True
# G1 mean ncut: 9.034358113266428
# G2 mean ncut: 8.682167450626666
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 9.104657392139233
# G2 mean ncut: 8.585493444973556
#
# relapsing_remitting
# G1 mean ncut: 9.01526667984731
# G2 mean ncut: 8.669909061241217
#
# secondary_progressive
# G1 mean ncut: 9.029680926122632
# G2 mean ncut: 8.684341874445021
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 9.05679990151145
# G2 mean ncut: 8.680479383224888
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 9.025951957187115
# G2 mean ncut: 8.677166142193258
#
# Vojta_reflex_locomotion
# G1 mean ncut: 9.009220363545065
# G2 mean ncut: 8.623601955726834
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: sex
#
# F
# G1 mean ncut: 10.03218980755176
# G2 mean ncut: 9.86849198179512
#
# M
# G1 mean ncut: 10.104722962137394
# G2 mean ncut: 9.851981460023277
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: age over 50
#
# False
# G1 mean ncut: 10.040807028670368
# G2 mean ncut: 9.864217892573908
#
# True
# G1 mean ncut: 10.085085078222411
# G2 mean ncut: 9.859475713824686
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 10.053843591392527
# G2 mean ncut: 9.862900945484478
#
# True
# G1 mean ncut: 10.070617933439054
# G2 mean ncut: 9.860888226297485
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 10.102263277654275
# G2 mean ncut: 9.824774940656171
#
# relapsing_remitting
# G1 mean ncut: 10.044387979073333
# G2 mean ncut: 9.858026568491628
#
# secondary_progressive
# G1 mean ncut: 10.073844002707812
# G2 mean ncut: 9.880411196715121
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 10.082417385728537
# G2 mean ncut: 9.869104088698084
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 10.045736859209981
# G2 mean ncut: 9.875765236921328
#
# Vojta_reflex_locomotion
# G1 mean ncut: 10.074859367766532
# G2 mean ncut: 9.819646592196506
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: sex
#
# F
# G1 mean ncut: 10.997105588562645
# G2 mean ncut: 10.80209603083615
#
# M
# G1 mean ncut: 11.017859018324069
# G2 mean ncut: 10.763107052370595
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: age over 50
#
# False
# G1 mean ncut: 10.990810642924572
# G2 mean ncut: 10.774221107684935
#
# True
# G1 mean ncut: 11.023696243801387
# G2 mean ncut: 10.804057603237437
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 10.983622216179722
# G2 mean ncut: 10.790615205906757
#
# True
# G1 mean ncut: 11.042091817429183
# G2 mean ncut: 10.781165341863838
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 11.054631998303202
# G2 mean ncut: 10.745029805390082
#
# relapsing_remitting
# G1 mean ncut: 11.004992920747984
# G2 mean ncut: 10.782389438136583
#
# secondary_progressive
# G1 mean ncut: 10.99030564515104
# G2 mean ncut: 10.807879780823843
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 11.053524406770947
# G2 mean ncut: 10.76999776855711
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 10.993335473799664
# G2 mean ncut: 10.807756130290988
#
# Vojta_reflex_locomotion
# G1 mean ncut: 10.987264677004656
# G2 mean ncut: 10.750410455717326
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: sex
#
# F
# G1 mean ncut: 12.032038648073383
# G2 mean ncut: 11.733437386377553
#
# M
# G1 mean ncut: 12.0578784082879
# G2 mean ncut: 11.685549426409025
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: age over 50
#
# False
# G1 mean ncut: 12.048485902533036
# G2 mean ncut: 11.711187029089114
#
# True
# G1 mean ncut: 12.033388949354372
# G2 mean ncut: 11.72017158132105
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 12.049688974165855
# G2 mean ncut: 11.7150945000803
#
# True
# G1 mean ncut: 12.028566015956107
# G2 mean ncut: 11.715055868196629
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 12.037173084836795
# G2 mean ncut: 11.694972006955828
#
# relapsing_remitting
# G1 mean ncut: 12.047429792937029
# G2 mean ncut: 11.702751222292852
#
# secondary_progressive
# G1 mean ncut: 12.034049095022855
# G2 mean ncut: 11.742072325184267
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 12.092755735184598
# G2 mean ncut: 11.718450113003607
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 12.017984768931237
# G2 mean ncut: 11.728806434740832
#
# Vojta_reflex_locomotion
# G1 mean ncut: 12.053794359098076
# G2 mean ncut: 11.675811527164772
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: sex
#
# F
# G1 mean ncut: 12.993049927342891
# G2 mean ncut: 12.830087461767226
#
# M
# G1 mean ncut: 12.995630605665122
# G2 mean ncut: 12.84425133787835
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: age over 50
#
# False
# G1 mean ncut: 12.992866606529269
# G2 mean ncut: 12.841816762270112
#
# True
# G1 mean ncut: 12.995572562307292
# G2 mean ncut: 12.827278728438674
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 13.000500427900851
# G2 mean ncut: 12.846871855150866
#
# True
# G1 mean ncut: 12.982878862806926
# G2 mean ncut: 12.815903925493473
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 13.059327806181601
# G2 mean ncut: 12.841927737947666
#
# relapsing_remitting
# G1 mean ncut: 12.990680887359225
# G2 mean ncut: 12.832711310858953
#
# secondary_progressive
# G1 mean ncut: 12.980161711734073
# G2 mean ncut: 12.838363292984948
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 13.016150461876304
# G2 mean ncut: 12.8814705692501
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 12.984160568937654
# G2 mean ncut: 12.840459859160008
#
# Vojta_reflex_locomotion
# G1 mean ncut: 12.99776429951635
# G2 mean ncut: 12.776635711145982
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: sex
#
# F
# G1 mean ncut: 14.100885169810994
# G2 mean ncut: 13.926177721036108
#
# M
# G1 mean ncut: 14.138018087329158
# G2 mean ncut: 13.871479493326598
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: age over 50
#
# False
# G1 mean ncut: 14.12239116500052
# G2 mean ncut: 13.90068157719457
#
# True
# G1 mean ncut: 14.105610295444604
# G2 mean ncut: 13.911131938470477
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 14.129895982733828
# G2 mean ncut: 13.898866196814337
#
# True
# G1 mean ncut: 14.089596361258726
# G2 mean ncut: 13.91616766117741
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 14.13913466844968
# G2 mean ncut: 13.860107707803033
#
# relapsing_remitting
# G1 mean ncut: 14.11638447594332
# G2 mean ncut: 13.915221557309279
#
# secondary_progressive
# G1 mean ncut: 14.105764354940323
# G2 mean ncut: 13.901721241475702
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 14.123700549755235
# G2 mean ncut: 13.906435274416928
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 14.11110782924282
# G2 mean ncut: 13.919959662712719
#
# Vojta_reflex_locomotion
# G1 mean ncut: 14.11703030388488
# G2 mean ncut: 13.865408994245785
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: sex
#
# F
# G1 mean ncut: 15.090587742688303
# G2 mean ncut: 14.77221199738682
#
# M
# G1 mean ncut: 15.093823546819365
# G2 mean ncut: 14.753791618697958
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: age over 50
#
# False
# G1 mean ncut: 15.080795677067139
# G2 mean ncut: 14.775562594356323
#
# True
# G1 mean ncut: 15.10625519369346
# G2 mean ncut: 14.751535497125019
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 15.092986375073368
# G2 mean ncut: 14.798065928100803
#
# True
# G1 mean ncut: 15.089827536523849
# G2 mean ncut: 14.708297539342494
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 15.124878619624647
# G2 mean ncut: 14.631638164117348
#
# relapsing_remitting
# G1 mean ncut: 15.082044560082652
# G2 mean ncut: 14.732858305207433
#
# secondary_progressive
# G1 mean ncut: 15.098545064787729
# G2 mean ncut: 14.86010198858043
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 15.117649160412807
# G2 mean ncut: 14.776709487012827
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 15.088687031690617
# G2 mean ncut: 14.74266511446113
#
# Vojta_reflex_locomotion
# G1 mean ncut: 15.074222299497311
# G2 mean ncut: 14.81240107004002
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: sex
#
# F
# G1 mean ncut: 15.995452331769886
# G2 mean ncut: 15.824141059039116
#
# M
# G1 mean ncut: 16.022022971381904
# G2 mean ncut: 15.793913907302086
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: age over 50
#
# False
# G1 mean ncut: 15.979152107130695
# G2 mean ncut: 15.81785102349985
#
# True
# G1 mean ncut: 16.040272806724083
# G2 mean ncut: 15.805627086669242
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 15.984044352024661
# G2 mean ncut: 15.840497686992626
#
# True
# G1 mean ncut: 16.042935420015116
# G2 mean ncut: 15.764287588485253
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 15.983230940298263
# G2 mean ncut: 15.745532290306272
#
# relapsing_remitting
# G1 mean ncut: 15.99737831465324
# G2 mean ncut: 15.814060015481104
#
# secondary_progressive
# G1 mean ncut: 16.0264008138635
# G2 mean ncut: 15.830100239210001
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 16.0455985672913
# G2 mean ncut: 15.77250840235867
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 15.989798258025747
# G2 mean ncut: 15.83113246945951
#
# Vojta_reflex_locomotion
# G1 mean ncut: 16.007103266892862
# G2 mean ncut: 15.804009681546862
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: sex
#
# F
# G1 mean ncut: 17.11292374046747
# G2 mean ncut: 16.814537372251138
#
# M
# G1 mean ncut: 17.1562961571076
# G2 mean ncut: 16.761442636795863
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: age over 50
#
# False
# G1 mean ncut: 17.121474893255584
# G2 mean ncut: 16.782185289324705
#
# True
# G1 mean ncut: 17.140109370772358
# G2 mean ncut: 16.809875522406035
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 17.125764663236396
# G2 mean ncut: 16.805829894834446
#
# True
# G1 mean ncut: 17.136087854899458
# G2 mean ncut: 16.774069427994906
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 17.167408640908217
# G2 mean ncut: 16.76019623317164
#
# relapsing_remitting
# G1 mean ncut: 17.15403598019391
# G2 mean ncut: 16.800499545065602
#
# secondary_progressive
# G1 mean ncut: 17.076565741936452
# G2 mean ncut: 16.793645074416833
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 17.180287072557974
# G2 mean ncut: 16.78637759832208
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 17.099362941135585
# G2 mean ncut: 16.788419696829685
#
# Vojta_reflex_locomotion
# G1 mean ncut: 17.157762928377505
# G2 mean ncut: 16.817068073015434
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: sex
#
# F
# G1 mean ncut: 17.963286860188763
# G2 mean ncut: 18.026795743725653
#
# M
# G1 mean ncut: 17.99635650775497
# G2 mean ncut: 17.975914117464516
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: age over 50
#
# False
# G1 mean ncut: 17.969549154414874
# G2 mean ncut: 17.99732350720203
#
# True
# G1 mean ncut: 17.984351625201647
# G2 mean ncut: 18.020325691333237
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 17.95503013547909
# G2 mean ncut: 18.015157604429472
#
# True
# G1 mean ncut: 18.012121288961055
# G2 mean ncut: 17.99370355687333
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 18.071819905423812
# G2 mean ncut: 17.993620051907445
#
# relapsing_remitting
# G1 mean ncut: 17.982732322258403
# G2 mean ncut: 18.00595731677035
#
# secondary_progressive
# G1 mean ncut: 17.935699755801004
# G2 mean ncut: 18.01365990689483
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 17.983589041797106
# G2 mean ncut: 17.997885677295276
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 17.96969565967746
# G2 mean ncut: 18.011595006894215
#
# Vojta_reflex_locomotion
# G1 mean ncut: 17.984731040996355
# G2 mean ncut: 18.005440244637793
#
# -------------------

# %% [markdown]
# Comparing the mean NCuts for n_clusters=2 between patients of different ages, it seems that patients under 51 years have a lower average ncut value than those over 50 in graph 1, but a higher average ncut value in graph 2. A higher ncut value means that the partitions are more similar to each other. Based on this result, we can speculate that ???\
# **insert more analysis here**

# %% [markdown]
# #### Deepwalk embeddings

# %%
# takes a while to run

individual_ncuts = []

for res in kmeans_ncut_results2:
    
    G1_ncuts = []
    G1_partition = res[3]
    for patient in G1s:
        G1_ncuts.append(ncut_by_k_partition(patient, G1_partition))

    G2_ncuts = []
    G2_partition = res[4]
    for patient in G2s:
        G2_ncuts.append(ncut_by_k_partition(patient, G2_partition))
        
    individual_ncuts.append([res[0], G1_ncuts, G2_ncuts])

# %%
attribute_statistics = []

for part_description, G1_ncuts, G2_ncuts in individual_ncuts:
    for comp_description, labels in comparison_attributes:
        
        label_ncuts_g1 = {}
        label_ncuts_g2 = {}
        
        for label in np.unique(labels):
            indices = np.where(labels == label)[0]
            
            # note: if desired, more descriptive statistics could be saved here
            stats = describe(np.asarray(G1_ncuts)[indices])
            label_ncuts_g1[label] = {'mean': stats.mean, 'variance': stats.variance}
            
            stats = describe(np.asarray(G2_ncuts)[indices])
            label_ncuts_g2[label] = {'mean': stats.mean, 'variance': stats.variance}
            
        attribute_statistics.append({'partition_name' : part_description, 'attribute_name' : comp_description,
                                    'G1' : label_ncuts_g1, 'G2' : label_ncuts_g2})

# %%
for entry in attribute_statistics:
    
    print("Partition:", entry['partition_name'])
    print("Attribute:", entry['attribute_name'], "\n")
    
    for key in entry['G1'].keys():
        print(key)
        print("G1 mean ncut:", entry['G1'][key]['mean'])
        print("G2 mean ncut:", entry['G2'][key]['mean'])
        print()
        
    print("-------------------")
# Out:
# Partition: KMeans n_clusters=2
# Attribute: sex
#
# F
# G1 mean ncut: 0.8134142484146929
# G2 mean ncut: 0.8125184923616151
#
# M
# G1 mean ncut: 0.8099525424292431
# G2 mean ncut: 0.781011784832379
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: age over 50
#
# False
# G1 mean ncut: 0.8177160266295395
# G2 mean ncut: 0.7941169871725611
#
# True
# G1 mean ncut: 0.8047265677619954
# G2 mean ncut: 0.8087106809483614
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 0.8037169308100777
# G2 mean ncut: 0.799014913618519
#
# True
# G1 mean ncut: 0.8265451043833305
# G2 mean ncut: 0.8029040250463978
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 0.8471059828231148
# G2 mean ncut: 0.7829114215973777
#
# relapsing_remitting
# G1 mean ncut: 0.8173212333340683
# G2 mean ncut: 0.8003662368936623
#
# secondary_progressive
# G1 mean ncut: 0.7926838918459606
# G2 mean ncut: 0.8058267342277844
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 0.8187514523280535
# G2 mean ncut: 0.8030687500763705
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 0.7998423656169265
# G2 mean ncut: 0.8003438805825267
#
# Vojta_reflex_locomotion
# G1 mean ncut: 0.8374481812289252
# G2 mean ncut: 0.7980668905942886
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: sex
#
# F
# G1 mean ncut: 1.4442241780577763
# G2 mean ncut: 1.4247172262143535
#
# M
# G1 mean ncut: 1.3903846296107876
# G2 mean ncut: 1.3466561296061534
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: age over 50
#
# False
# G1 mean ncut: 1.4417699407392295
# G2 mean ncut: 1.3999168304130878
#
# True
# G1 mean ncut: 1.3998062724635394
# G2 mean ncut: 1.3880944660318317
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 1.415372270485421
# G2 mean ncut: 1.4047931463148784
#
# True
# G1 mean ncut: 1.4377724904881743
# G2 mean ncut: 1.3775222177685107
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 1.3924791743536435
# G2 mean ncut: 1.3608081324745533
#
# relapsing_remitting
# G1 mean ncut: 1.440008672990996
# G2 mean ncut: 1.4006436269733453
#
# secondary_progressive
# G1 mean ncut: 1.4049985570685053
# G2 mean ncut: 1.3950448119465775
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 1.4157104674104313
# G2 mean ncut: 1.3961201817003828
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 1.4068991301884406
# G2 mean ncut: 1.3853102295038808
#
# Vojta_reflex_locomotion
# G1 mean ncut: 1.4751026589571727
# G2 mean ncut: 1.4182706296642837
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: sex
#
# F
# G1 mean ncut: 2.1414406656054013
# G2 mean ncut: 2.0786514549131145
#
# M
# G1 mean ncut: 2.109455193544491
# G2 mean ncut: 2.041125523078821
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: age over 50
#
# False
# G1 mean ncut: 2.1661188317867346
# G2 mean ncut: 2.0674526154177335
#
# True
# G1 mean ncut: 2.080874376852853
# G2 mean ncut: 2.0601000745536613
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 2.1244527503776367
# G2 mean ncut: 2.0815838195831846
#
# True
# G1 mean ncut: 2.1373440711169533
# G2 mean ncut: 2.0343548053835043
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 2.1062901685044886
# G2 mean ncut: 2.051155844259907
#
# relapsing_remitting
# G1 mean ncut: 2.1606055960674735
# G2 mean ncut: 2.066458690988108
#
# secondary_progressive
# G1 mean ncut: 2.082622140080106
# G2 mean ncut: 2.0644730151721506
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 2.135663406518251
# G2 mean ncut: 2.0747068387438006
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 2.0986437265414843
# G2 mean ncut: 2.06355732376617
#
# Vojta_reflex_locomotion
# G1 mean ncut: 2.2025586993673403
# G2 mean ncut: 2.055680996221457
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: sex
#
# F
# G1 mean ncut: 3.015231755172305
# G2 mean ncut: 3.0174677334317717
#
# M
# G1 mean ncut: 2.995203160812625
# G2 mean ncut: 2.988880884003011
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: age over 50
#
# False
# G1 mean ncut: 3.0218383006269223
# G2 mean ncut: 2.9968171729242634
#
# True
# G1 mean ncut: 2.988874823798088
# G2 mean ncut: 3.01918394575461
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 3.0015597547441897
# G2 mean ncut: 3.0274324631138163
#
# True
# G1 mean ncut: 3.0179080436266563
# G2 mean ncut: 2.970369675941809
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 3.0023620180553965
# G2 mean ncut: 3.0337564646486306
#
# relapsing_remitting
# G1 mean ncut: 3.0274458531462933
# G2 mean ncut: 3.0034070111416704
#
# secondary_progressive
# G1 mean ncut: 2.975295826237965
# G2 mean ncut: 3.0036094651168126
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 3.0237197551936528
# G2 mean ncut: 3.0134565662288493
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 2.976962904252341
# G2 mean ncut: 2.9972180411384084
#
# Vojta_reflex_locomotion
# G1 mean ncut: 3.071396313689891
# G2 mean ncut: 3.0238629007203004
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: sex
#
# F
# G1 mean ncut: 3.8039092993122536
# G2 mean ncut: 3.8534566786703253
#
# M
# G1 mean ncut: 3.7769247276990434
# G2 mean ncut: 3.79274364350131
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: age over 50
#
# False
# G1 mean ncut: 3.8001204082524715
# G2 mean ncut: 3.822233301024617
#
# True
# G1 mean ncut: 3.784993035809516
# G2 mean ncut: 3.8405795644805845
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 3.77061719061948
# G2 mean ncut: 3.825952792076735
#
# True
# G1 mean ncut: 3.8332027076405093
# G2 mean ncut: 3.8374906732916476
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 3.869802567087943
# G2 mean ncut: 3.7825566238562547
#
# relapsing_remitting
# G1 mean ncut: 3.796307778204032
# G2 mean ncut: 3.846087707597153
#
# secondary_progressive
# G1 mean ncut: 3.766031647508335
# G2 mean ncut: 3.8174339554945727
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 3.8085362277359796
# G2 mean ncut: 3.8544077151376746
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 3.763357523905195
# G2 mean ncut: 3.822947095638702
#
# Vojta_reflex_locomotion
# G1 mean ncut: 3.857598926022085
# G2 mean ncut: 3.824884566371274
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: sex
#
# F
# G1 mean ncut: 4.7630917137183415
# G2 mean ncut: 4.745173608684004
#
# M
# G1 mean ncut: 4.709930215980134
# G2 mean ncut: 4.662000083060558
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: age over 50
#
# False
# G1 mean ncut: 4.78527406006751
# G2 mean ncut: 4.700606709636241
#
# True
# G1 mean ncut: 4.687056551262551
# G2 mean ncut: 4.72987681938726
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 4.736015268793662
# G2 mean ncut: 4.7223201667731605
#
# True
# G1 mean ncut: 4.75428218913466
# G2 mean ncut: 4.697693595196402
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 4.744344126779527
# G2 mean ncut: 4.69895816254487
#
# relapsing_remitting
# G1 mean ncut: 4.779833317183341
# G2 mean ncut: 4.714964718213406
#
# secondary_progressive
# G1 mean ncut: 4.679119541510547
# G2 mean ncut: 4.714743801858794
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 4.774785839648914
# G2 mean ncut: 4.730619137655935
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 4.709581315908918
# G2 mean ncut: 4.718432583109512
#
# Vojta_reflex_locomotion
# G1 mean ncut: 4.7972929014448145
# G2 mean ncut: 4.6825129858807975
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: sex
#
# F
# G1 mean ncut: 5.514201743984916
# G2 mean ncut: 5.548405224765463
#
# M
# G1 mean ncut: 5.469457326485325
# G2 mean ncut: 5.495885632657148
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: age over 50
#
# False
# G1 mean ncut: 5.5129777519583545
# G2 mean ncut: 5.49627840460722
#
# True
# G1 mean ncut: 5.4762207488469326
# G2 mean ncut: 5.570111427338118
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 5.471336694019731
# G2 mean ncut: 5.534362621362233
#
# True
# G1 mean ncut: 5.5414631210842975
# G2 mean ncut: 5.517753784348715
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 5.546328852277942
# G2 mean ncut: 5.580950939797706
#
# relapsing_remitting
# G1 mean ncut: 5.511969039351127
# G2 mean ncut: 5.517636433298358
#
# secondary_progressive
# G1 mean ncut: 5.456903129249918
# G2 mean ncut: 5.530550924825308
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 5.5363937108246395
# G2 mean ncut: 5.6027932758929335
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 5.458470383907741
# G2 mean ncut: 5.520741492413328
#
# Vojta_reflex_locomotion
# G1 mean ncut: 5.558605518693909
# G2 mean ncut: 5.473449195290404
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: sex
#
# F
# G1 mean ncut: 6.491472075426352
# G2 mean ncut: 6.561531729416122
#
# M
# G1 mean ncut: 6.457205240249025
# G2 mean ncut: 6.494174019781408
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: age over 50
#
# False
# G1 mean ncut: 6.487126777126782
# G2 mean ncut: 6.4872103546269875
#
# True
# G1 mean ncut: 6.466841419007385
# G2 mean ncut: 6.599135553309666
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 6.459109200855905
# G2 mean ncut: 6.533009696689693
#
# True
# G1 mean ncut: 6.511547167453554
# G2 mean ncut: 6.540377634961843
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 6.5370951549793626
# G2 mean ncut: 6.585056769802695
#
# relapsing_remitting
# G1 mean ncut: 6.4739241499872335
# G2 mean ncut: 6.543492036472732
#
# secondary_progressive
# G1 mean ncut: 6.4682097643530225
# G2 mean ncut: 6.507680329223993
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 6.486257591105043
# G2 mean ncut: 6.585220671766743
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 6.458158376927673
# G2 mean ncut: 6.514658763973081
#
# Vojta_reflex_locomotion
# G1 mean ncut: 6.523188755122782
# G2 mean ncut: 6.541262287332036
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: sex
#
# F
# G1 mean ncut: 7.589943672987412
# G2 mean ncut: 7.324944349156416
#
# M
# G1 mean ncut: 7.582286830606165
# G2 mean ncut: 7.200757646146399
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: age over 50
#
# False
# G1 mean ncut: 7.581725199861587
# G2 mean ncut: 7.2089160866301185
#
# True
# G1 mean ncut: 7.593917546507006
# G2 mean ncut: 7.366816147489638
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 7.559931275396508
# G2 mean ncut: 7.273646490971758
#
# True
# G1 mean ncut: 7.633778388154945
# G2 mean ncut: 7.2837181874194465
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 7.68795233803685
# G2 mean ncut: 7.342929375905862
#
# relapsing_remitting
# G1 mean ncut: 7.600222806422549
# G2 mean ncut: 7.2660407479262945
#
# secondary_progressive
# G1 mean ncut: 7.534261177894417
# G2 mean ncut: 7.276870254761269
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 7.645683933223942
# G2 mean ncut: 7.306656129455383
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 7.556487354994095
# G2 mean ncut: 7.269252930769372
#
# Vojta_reflex_locomotion
# G1 mean ncut: 7.608157830981974
# G2 mean ncut: 7.26917211162123
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: sex
#
# F
# G1 mean ncut: 8.31232579391463
# G2 mean ncut: 8.311128486548041
#
# M
# G1 mean ncut: 8.320129117616563
# G2 mean ncut: 8.230412634215496
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: age over 50
#
# False
# G1 mean ncut: 8.315037486075445
# G2 mean ncut: 8.221172748566735
#
# True
# G1 mean ncut: 8.315682675132967
# G2 mean ncut: 8.357360428383263
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 8.289475793853558
# G2 mean ncut: 8.265827243380423
#
# True
# G1 mean ncut: 8.359951996072141
# G2 mean ncut: 8.304991333671715
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 8.478576119395404
# G2 mean ncut: 8.37697007392484
#
# relapsing_remitting
# G1 mean ncut: 8.31529502280756
# G2 mean ncut: 8.273552190583814
#
# secondary_progressive
# G1 mean ncut: 8.26637682940964
# G2 mean ncut: 8.262432483291756
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 8.397510382410504
# G2 mean ncut: 8.317113887301609
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 8.276443295619437
# G2 mean ncut: 8.259566260076967
#
# Vojta_reflex_locomotion
# G1 mean ncut: 8.334793619817297
# G2 mean ncut: 8.297193170130457
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: sex
#
# F
# G1 mean ncut: 9.349390179641237
# G2 mean ncut: 9.032142848124664
#
# M
# G1 mean ncut: 9.327460318815048
# G2 mean ncut: 8.948870644371175
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: age over 50
#
# False
# G1 mean ncut: 9.36395661542087
# G2 mean ncut: 8.934924323465637
#
# True
# G1 mean ncut: 9.310942271352392
# G2 mean ncut: 9.085610892435305
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 9.318737412978098
# G2 mean ncut: 8.987499827407527
#
# True
# G1 mean ncut: 9.379409194832004
# G2 mean ncut: 9.022196216348341
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 9.507515796830395
# G2 mean ncut: 9.00327799859282
#
# relapsing_remitting
# G1 mean ncut: 9.326138527793033
# G2 mean ncut: 8.978663960873627
#
# secondary_progressive
# G1 mean ncut: 9.316260962676319
# G2 mean ncut: 9.035953376994467
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 9.444651652003587
# G2 mean ncut: 9.016446593947503
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 9.283590886506897
# G2 mean ncut: 9.00337539857327
#
# Vojta_reflex_locomotion
# G1 mean ncut: 9.387420181706974
# G2 mean ncut: 8.975749302180068
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: sex
#
# F
# G1 mean ncut: 10.116338776644604
# G2 mean ncut: 10.124397141613134
#
# M
# G1 mean ncut: 10.073912762755233
# G2 mean ncut: 10.037664208436677
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: age over 50
#
# False
# G1 mean ncut: 10.103636489691622
# G2 mean ncut: 10.06064211746425
#
# True
# G1 mean ncut: 10.095418754988675
# G2 mean ncut: 10.131043809228656
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 10.080760500306669
# G2 mean ncut: 10.087445413991585
#
# True
# G1 mean ncut: 10.133437693980328
# G2 mean ncut: 10.097547513729513
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 10.20294879032266
# G2 mean ncut: 10.176084216773473
#
# relapsing_remitting
# G1 mean ncut: 10.08357582883191
# G2 mean ncut: 10.109923879275959
#
# secondary_progressive
# G1 mean ncut: 10.097262867849992
# G2 mean ncut: 10.033752691885303
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 10.203801379058323
# G2 mean ncut: 10.119747414227115
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 10.06056920260444
# G2 mean ncut: 10.062396359502934
#
# Vojta_reflex_locomotion
# G1 mean ncut: 10.099673650993195
# G2 mean ncut: 10.13775218659055
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: sex
#
# F
# G1 mean ncut: 11.116937531370633
# G2 mean ncut: 11.030553306174706
#
# M
# G1 mean ncut: 11.064004723691065
# G2 mean ncut: 11.000328786172416
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: age over 50
#
# False
# G1 mean ncut: 11.095774885732641
# G2 mean ncut: 10.96614459347633
#
# True
# G1 mean ncut: 11.097786584257621
# G2 mean ncut: 11.088043008932091
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 11.06134597632614
# G2 mean ncut: 11.023988239809748
#
# True
# G1 mean ncut: 11.157620463873396
# G2 mean ncut: 11.010294604439055
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 11.295320240796476
# G2 mean ncut: 11.113524759276386
#
# relapsing_remitting
# G1 mean ncut: 11.065625234291964
# G2 mean ncut: 11.007912058655505
#
# secondary_progressive
# G1 mean ncut: 11.089780894745115
# G2 mean ncut: 11.009393793024207
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 11.177828955882699
# G2 mean ncut: 11.178136870056154
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 11.061162188221306
# G2 mean ncut: 10.976787303189864
#
# Vojta_reflex_locomotion
# G1 mean ncut: 11.108269729200646
# G2 mean ncut: 10.970114368557246
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: sex
#
# F
# G1 mean ncut: 11.936175700173822
# G2 mean ncut: 11.492779128035048
#
# M
# G1 mean ncut: 11.923896894534394
# G2 mean ncut: 11.45221538905876
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: age over 50
#
# False
# G1 mean ncut: 11.926972863482884
# G2 mean ncut: 11.420677823102313
#
# True
# G1 mean ncut: 11.93734815855017
# G2 mean ncut: 11.551182142314211
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 11.899170737063837
# G2 mean ncut: 11.488650836891319
#
# True
# G1 mean ncut: 11.987256430558936
# G2 mean ncut: 11.45750226744446
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 12.191956120049214
# G2 mean ncut: 11.558933414327152
#
# relapsing_remitting
# G1 mean ncut: 11.898873773568603
# G2 mean ncut: 11.459646217250334
#
# secondary_progressive
# G1 mean ncut: 11.908734222954731
# G2 mean ncut: 11.482610490658697
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 12.075796596730886
# G2 mean ncut: 11.604865707831568
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 11.883240418729217
# G2 mean ncut: 11.431712402161258
#
# Vojta_reflex_locomotion
# G1 mean ncut: 11.91327688357135
# G2 mean ncut: 11.468638908488856
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: sex
#
# F
# G1 mean ncut: 12.917860938348266
# G2 mean ncut: 12.4425847627567
#
# M
# G1 mean ncut: 12.900987430648653
# G2 mean ncut: 12.473349905676734
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: age over 50
#
# False
# G1 mean ncut: 12.931580121354951
# G2 mean ncut: 12.409209949899786
#
# True
# G1 mean ncut: 12.884993903759096
# G2 mean ncut: 12.513444067537316
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 12.887813899798362
# G2 mean ncut: 12.488382508675587
#
# True
# G1 mean ncut: 12.952119883248507
# G2 mean ncut: 12.395643123767757
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 13.16048337165433
# G2 mean ncut: 12.573426361721792
#
# relapsing_remitting
# G1 mean ncut: 12.859250949951601
# G2 mean ncut: 12.434465525997117
#
# secondary_progressive
# G1 mean ncut: 12.925306654776227
# G2 mean ncut: 12.452514899916508
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 13.049563000214821
# G2 mean ncut: 12.615595086634924
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 12.8593408007715
# G2 mean ncut: 12.39220564864484
#
# Vojta_reflex_locomotion
# G1 mean ncut: 12.909358414983172
# G2 mean ncut: 12.455765836337251
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: sex
#
# F
# G1 mean ncut: 13.882974289363919
# G2 mean ncut: 13.806022073477287
#
# M
# G1 mean ncut: 13.884923872760794
# G2 mean ncut: 13.80604626022276
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: age over 50
#
# False
# G1 mean ncut: 13.884094012672941
# G2 mean ncut: 13.777525692880486
#
# True
# G1 mean ncut: 13.883234667272433
# G2 mean ncut: 13.843307967147942
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 13.874011135756666
# G2 mean ncut: 13.806044611531592
#
# True
# G1 mean ncut: 13.900494300964086
# G2 mean ncut: 13.806008430253748
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 14.026040556847306
# G2 mean ncut: 13.992804253830405
#
# relapsing_remitting
# G1 mean ncut: 13.857382306412195
# G2 mean ncut: 13.781193939050038
#
# secondary_progressive
# G1 mean ncut: 13.885802801043237
# G2 mean ncut: 13.79222306265497
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 14.00216347645581
# G2 mean ncut: 13.992026499860854
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 13.83629205921444
# G2 mean ncut: 13.74491375076418
#
# Vojta_reflex_locomotion
# G1 mean ncut: 13.889326351749755
# G2 mean ncut: 13.779882206123832
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: sex
#
# F
# G1 mean ncut: 15.03325571710116
# G2 mean ncut: 14.485832976812866
#
# M
# G1 mean ncut: 14.978069833679948
# G2 mean ncut: 14.387827794520302
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: age over 50
#
# False
# G1 mean ncut: 15.012829560307683
# G2 mean ncut: 14.355022435097052
#
# True
# G1 mean ncut: 15.011148563727707
# G2 mean ncut: 14.570196023951665
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 14.966378815504541
# G2 mean ncut: 14.397395737800423
#
# True
# G1 mean ncut: 15.091076032645871
# G2 mean ncut: 14.536128244528498
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 15.19405553509909
# G2 mean ncut: 14.580023831421412
#
# relapsing_remitting
# G1 mean ncut: 14.985455802465731
# G2 mean ncut: 14.431907307377056
#
# secondary_progressive
# G1 mean ncut: 15.002811860647608
# G2 mean ncut: 14.436543398834733
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 15.147181040665968
# G2 mean ncut: 14.579725266190653
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 14.971844692393724
# G2 mean ncut: 14.409688768367895
#
# Vojta_reflex_locomotion
# G1 mean ncut: 14.982307279795187
# G2 mean ncut: 14.417693294696628
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: sex
#
# F
# G1 mean ncut: 15.615318967005038
# G2 mean ncut: 15.854217564689161
#
# M
# G1 mean ncut: 15.589006924037934
# G2 mean ncut: 15.810705641076812
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: age over 50
#
# False
# G1 mean ncut: 15.568540978627546
# G2 mean ncut: 15.786854648582796
#
# True
# G1 mean ncut: 15.653214144566245
# G2 mean ncut: 15.903816214863486
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 15.552186724179338
# G2 mean ncut: 15.805810342545158
#
# True
# G1 mean ncut: 15.696857523329276
# G2 mean ncut: 15.892340300979537
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 15.865935945052527
# G2 mean ncut: 16.042469036218368
#
# relapsing_remitting
# G1 mean ncut: 15.548438255675153
# G2 mean ncut: 15.809336297100709
#
# secondary_progressive
# G1 mean ncut: 15.623572233439422
# G2 mean ncut: 15.82400156597657
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 15.718228393728326
# G2 mean ncut: 15.921084299658848
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 15.554363270512367
# G2 mean ncut: 15.835102138380869
#
# Vojta_reflex_locomotion
# G1 mean ncut: 15.625280055090013
# G2 mean ncut: 15.760362387519324
#
# -------------------

# %% [markdown]
# # Task 2d

# %%
functions = (
    nx.conductance,
    nx.cut_size,
    nx.edge_expansion,
    nx.mixing_expansion,
)

results = pd.DataFrame()
results['graph'] = ['G1', 'G2']

# only compare k=2 at position 0
# get the two k means clusterings
clustering1, clustering2 = kmeans_ncut_results[0][-2:]

# parameter embedding 1
params1 = (
    G1,
    list(np.where(clustering1==0)[0]),
    list(np.where(clustering1==1)[0]),
)

# parameter embedding 2
params2 = (
    G2,
    list(np.where(clustering2==0)[0]),
    list(np.where(clustering2==1)[0]),
)



for func in functions:

    results[func.__name__] = [func(*params1), func(*params2)]

results
# Out:
#   graph  conductance  cut_size  edge_expansion  mixing_expansion
# 0    G1     0.371081      6842      207.333333          0.064083
# 1    G2     0.387704      9037      220.414634          0.086098

# %%
functions = (
    nx.conductance,
    nx.cut_size,
    nx.edge_expansion,
    nx.mixing_expansion,
)

results = pd.DataFrame()
results['graph'] = ['G1', 'G2']

# only compare k=2 at position 0
# get the two k means clusterings
clustering1, clustering2 = kmeans_ncut_results2[0][-2:]

# parameter embedding 1
params1 = (
    G1,
    list(np.where(clustering1==0)[0]),
    list(np.where(clustering1==1)[0]),
)

# parameter embedding 2
params2 = (
    G2,
    list(np.where(clustering2==0)[0]),
    list(np.where(clustering2==1)[0]),
)



for func in functions:

    results[func.__name__] = [func(*params1), func(*params2)]

results

# %%
functions = (
    nx.boundary_expansion,
    nx.node_expansion,
    nx.volume,
)


results = []

for i, n in enumerate(n_clusters):
    df = pd.DataFrame(columns=['graph', 'partition', *[f.__name__ for f in functions]])
    for (G_str, G), cluster in  product({'G1': G1, 'G2': G2}.items(), list(range(n))):
        # a bit hacky
        if G_str == 'G1': clustering = kmeans_ncut_results[i][-2]
        else: clustering = kmeans_ncut_results[i][-1]

        df.loc[len(df.index)] = [
            G_str, cluster,
            *[f(G, np.where(clustering==cluster)[0]) for f in functions]
        ]
    results.append(df)

# %%
functions = (
    nx.boundary_expansion,
    nx.node_expansion,
    nx.volume,
)


results = []

for i, n in enumerate(n_clusters):
    df = pd.DataFrame(columns=['graph', 'partition', *[f.__name__ for f in functions]])
    for (G_str, G), cluster in  product({'G1': G1, 'G2': G2}.items(), list(range(n))):
        # a bit hacky
        if G_str == 'G1': clustering = kmeans_ncut_results2[i][-2]
        else: clustering = kmeans_ncut_results2[i][-1]

        df.loc[len(df.index)] = [
            G_str, cluster,
            *[f(G, np.where(clustering==cluster)[0]) for f in functions]
        ]
    results.append(df)

# %%
results[2]
# Out:
#   graph  partition  boundary_expansion  node_expansion  volume
# 0    G1          0            3.461538        4.461538   15698
# 1    G1          1            0.757576        1.757576   74935
# 2    G1          2            4.272727        5.272727   15587
# 3    G1          3           48.500000       49.500000     548
# 4    G2          0            2.222222        3.222222   34461
# 5    G2          1            3.142857        4.142857   15928
# 6    G2          2            2.052632        3.052632   46400
# 7    G2          3            7.285714        8.285714    8173
