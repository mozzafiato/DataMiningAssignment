# %% [markdown]
# # Task 2c

# %%
import torch
import os
import networkx as nx
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score
from scipy.stats import describe
import ncut

# %% [markdown]
# ### Loading the graphs

# %% [markdown]
# Graph loading functions, could be changed to load multigraph directly from file

# %%
def csv_to_graph(path, threshold=0.3):
    # load in csv as dataframe
    df = pd.read_csv(path,header=None)
    
    # threshold dataframe and remove diagonal
    A = (df>threshold).astype(int) - pd.DataFrame(np.identity(df.shape[0]))
         
    # convert to graph
    G = nx.from_pandas_adjacency(A)
    
    return G

def load_graphs(folder):
    #load in all graphs in folder
    G1s, G2s = [],[]

    for i in range(1,61):
        filename = f'{folder}/p{i:03}_1.csv'
        G1s.append(csv_to_graph(filename))

        filename = f'{folder}/p{i:03}_2.csv'
        G2s.append(csv_to_graph(filename))
        
    return G1s, G2s

G1s, G2s = load_graphs("FC")

# %%
def graph_list_to_multigraph(graphs):
    G = nx.MultiGraph()
    for subgraph in graphs:
        G.add_nodes_from(subgraph.nodes)
        G.add_edges_from(subgraph.edges)
    return G

# %%
G1 = graph_list_to_multigraph(G1s)
G2 = graph_list_to_multigraph(G2s)

# %% [markdown]
# ### Loading the embeddings

# %%
EMBEDDING_DIR = "embedding_pickles"
G1_PATH = "best_G1_DMGI.pkl"
G2_PATH = "best_G2_DMGI.pkl"

# %%
g1_model = torch.load(os.path.join(EMBEDDING_DIR, G1_PATH))
g1_embedding = g1_model['H'].squeeze()

g2_model = torch.load(os.path.join(EMBEDDING_DIR, G2_PATH))
g2_embedding = g2_model['H'].squeeze()

# %%
g1_embedding.shape
# Out:
# torch.Size([116, 64])

# %% [markdown]
# ### Loading additional clinical data

# %%
clinical_csv = pd.read_csv("clinical.csv")
clinical_csv
# Out:
#       ID SEX                MS_TYPE  AGE  EDSS  DATASET  DIAG_YEARS     BMI  \
# 0   p001   M    primary_progressive   40     7        2          11  19.918
# 1   p002   M  secondary_progressive   44     7        2          17  20.529
# 2   p003   M    primary_progressive   51     6        2          21  25.249
# 3   p004   M    relapsing_remitting   29     3        2           9  21.500
# 4   p005   F  secondary_progressive   60     6        2          21  21.411
# 5   p006   M  secondary_progressive   68     4        2           7  21.605
# 6   p007   F    relapsing_remitting   36     4        2           9  19.370
# 7   p008   F    relapsing_remitting   32     4        2           4  19.141
# 8   p009   F    relapsing_remitting   35     4        1          20  16.436
# 9   p010   M  secondary_progressive   54     6        2          12  23.148
# 10  p011   M    relapsing_remitting   45     6        2          15  24.516
# 11  p012   M    relapsing_remitting   39     2        2          12  18.937
# 12  p013   F    relapsing_remitting   58     4        2          13  25.510
# 13  p014   M    primary_progressive   42     4        2           8  21.267
# 14  p015   F    relapsing_remitting   44     2        2          14  27.885
# 15  p016   M    relapsing_remitting   43     2        2          18  25.249
# 16  p017   M    relapsing_remitting   43     3        2          11  20.831
# 17  p018   F  secondary_progressive   53     5        2          17  35.380
# 18  p019   F  secondary_progressive   59     6        2          12  30.477
# 19  p020   F  secondary_progressive   58     4        2          19  20.833
# 20  p021   F  secondary_progressive   45     5        2          20  21.201
# 21  p022   M    relapsing_remitting   54     4        2          13  28.710
# 22  p023   M    primary_progressive   54     4        2           2  32.028
# 23  p024   F  secondary_progressive   38     5        2          17  22.656
# 24  p025   F  secondary_progressive   65     6        2          31  21.484
# 25  p026   M    relapsing_remitting   40     5        2          13  20.831
# 26  p027   F    relapsing_remitting   41     4        2           4  28.735
# 27  p028   F    relapsing_remitting   45     6        1           3  28.842
# 28  p029   F    relapsing_remitting   55     6        2          21  26.730
# 29  p030   M    relapsing_remitting   56     4        2           6  36.296
# 30  p031   F  secondary_progressive   56     5        2          14  21.755
# 31  p032   F    primary_progressive   59     4        2           4  26.573
# 32  p033   F    relapsing_remitting   39     5        1          15  18.145
# 33  p034   F    relapsing_remitting   22     1        1           1  21.107
# 34  p035   M  secondary_progressive   41     6        2           8  20.984
# 35  p036   F    relapsing_remitting   32     2        1           8  23.837
# 36  p037   M    relapsing_remitting   36     6        1          14  25.592
# 37  p038   F    relapsing_remitting   40     6        1          15  20.428
# 38  p039   F    relapsing_remitting   43     1        1          12  27.942
# 39  p040   F    relapsing_remitting   45     5        1          16  27.042
# 40  p041   F  secondary_progressive   35     5        1           8  21.830
# 41  p042   M    relapsing_remitting   40     2        1           9  19.818
# 42  p043   F    relapsing_remitting   50     3        1          10  22.137
# 43  p044   F  secondary_progressive   48     5        1          23  22.833
# 44  p045   M    relapsing_remitting   39     4        1          11  31.699
# 45  p046   F  secondary_progressive   63     4        1           3  23.809
# 46  p047   F  secondary_progressive   63     6        1          38  22.039
# 47  p048   F    relapsing_remitting   61     3        1          13  20.576
# 48  p049   F  secondary_progressive   58     4        1           4  33.802
# 49  p050   M    primary_progressive   53     1        1           1  24.057
# 50  p051   F  secondary_progressive   61     4        1           9  25.014
# 51  p052   M    relapsing_remitting   53     4        1           7  25.952
# 52  p053   F    relapsing_remitting   51     4        1          18  22.477
# 53  p054   M  secondary_progressive   63     6        1          22  21.701
# 54  p055   F  secondary_progressive   70     4        1          10  20.701
# 55  p056   F    relapsing_remitting   67     3        1          22  29.001
# 56  p057   M    relapsing_remitting   50     6        1          11  24.691
# 57  p058   F    relapsing_remitting   47     6        1          17  24.447
# 58  p059   F    relapsing_remitting   29     3        2           9  20.904
# 59  p060   F    relapsing_remitting   38     2        1          11  25.654
#
#                              THERAPY  outliers_V1  outliers_V2
# 0    Functional_electric_stimulation            0           14
# 1   Motor_Program_Activating_Therapy            4            0
# 2    Functional_electric_stimulation            4            0
# 3    Functional_electric_stimulation            4            2
# 4    Functional_electric_stimulation            0            4
# 5   Motor_Program_Activating_Therapy            2            3
# 6    Functional_electric_stimulation            6            7
# 7    Functional_electric_stimulation            5            7
# 8   Motor_Program_Activating_Therapy            3            0
# 9   Motor_Program_Activating_Therapy           20            6
# 10   Functional_electric_stimulation            0            2
# 11  Motor_Program_Activating_Therapy            0            2
# 12  Motor_Program_Activating_Therapy           38           13
# 13  Motor_Program_Activating_Therapy            0            3
# 14  Motor_Program_Activating_Therapy            4            0
# 15   Functional_electric_stimulation            0            6
# 16   Functional_electric_stimulation            0            0
# 17   Functional_electric_stimulation            2            4
# 18  Motor_Program_Activating_Therapy            4           42
# 19   Functional_electric_stimulation            0            2
# 20  Motor_Program_Activating_Therapy            0            0
# 21  Motor_Program_Activating_Therapy            0            0
# 22   Functional_electric_stimulation           19            6
# 23  Motor_Program_Activating_Therapy            0            0
# 24  Motor_Program_Activating_Therapy            0            0
# 25  Motor_Program_Activating_Therapy            0            0
# 26  Motor_Program_Activating_Therapy            0            0
# 27           Vojta_reflex_locomotion            0            2
# 28  Motor_Program_Activating_Therapy            0            0
# 29  Motor_Program_Activating_Therapy            4            9
# 30   Functional_electric_stimulation            0            2
# 31  Motor_Program_Activating_Therapy            0            5
# 32           Vojta_reflex_locomotion            4            0
# 33           Vojta_reflex_locomotion            0            0
# 34  Motor_Program_Activating_Therapy           10           25
# 35           Vojta_reflex_locomotion            0            0
# 36           Vojta_reflex_locomotion            0            5
# 37           Vojta_reflex_locomotion            2            2
# 38  Motor_Program_Activating_Therapy            2            0
# 39  Motor_Program_Activating_Therapy           10           30
# 40  Motor_Program_Activating_Therapy            4            6
# 41           Vojta_reflex_locomotion            0            0
# 42  Motor_Program_Activating_Therapy            4            2
# 43  Motor_Program_Activating_Therapy            2            4
# 44           Vojta_reflex_locomotion            2            4
# 45           Vojta_reflex_locomotion            3            9
# 46  Motor_Program_Activating_Therapy           41           21
# 47  Motor_Program_Activating_Therapy            0            0
# 48  Motor_Program_Activating_Therapy            4            2
# 49           Vojta_reflex_locomotion            0            2
# 50  Motor_Program_Activating_Therapy            8            3
# 51           Vojta_reflex_locomotion            6            3
# 52  Motor_Program_Activating_Therapy            0            5
# 53  Motor_Program_Activating_Therapy            8            0
# 54  Motor_Program_Activating_Therapy            5            0
# 55  Motor_Program_Activating_Therapy            2           14
# 56           Vojta_reflex_locomotion            0            0
# 57  Motor_Program_Activating_Therapy            0            0
# 58  Motor_Program_Activating_Therapy            0            0
# 59           Vojta_reflex_locomotion            0            0

# %% [markdown]
# ## Validation of our NCut implementation
# Validates our implementation of NCut against networkx by comparing the NCut values of random binary graph partitions.

# %%
# binary partitions validation on multigraphs

identical = True
graphs = [G1, G2]

n_checks = 10
precision = 1e-10

for i in range(n_checks):
    
        print(f"Checking random partition no. {i}")
        clustering = np.random.randint(0, 2, size=len(G1.nodes))
        
        for graph in graphs:
            nx_result = nx.normalized_cut_size(graph, np.where(clustering==0)[0], np.where(clustering==1)[0])
            our_result = ncut.ncut_multigraph(graph, np.where(clustering==0)[0], np.where(clustering==1)[0])
            our_k_result = ncut.k_ncut_multigraph(graph,  np.asarray([np.where(clustering==0)[0], np.where(clustering==1)[0]]))
            
            if abs(our_result - nx_result) > precision or abs(our_k_result - nx_result) > precision:
                identical = False
                break
        
        else:
            continue
        
        break

print(f"\nOur results were{' ' if identical else ' not '}identical to those of networkx for {n_checks} random partitions.")
# Out:
# Checking random partition no. 0
# Checking random partition no. 1
# C:\Users\micha\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# Checking random partition no. 2
# Checking random partition no. 3
# Checking random partition no. 4
# Checking random partition no. 5
# Checking random partition no. 6
# Checking random partition no. 7
# Checking random partition no. 8
# Checking random partition no. 9
#
# Our results were identical to those of networkx for 10 random partitions.

# %%
# binary partitions validation on single graphs

identical = True
graphs = [G1s, G2s]

n_checks = 10
precision = 1e-10

for i in range(n_checks):
    
        print(f"Checking random partition no. {i}")
        clustering = np.random.randint(0, 2, size=len(G1.nodes))
        
        for graph in graphs:
            for subgraph in graph:
                nx_result = nx.normalized_cut_size(subgraph, np.where(clustering==0)[0], np.where(clustering==1)[0])
                our_single_result = ncut.ncut_single_graph(subgraph, np.where(clustering==0)[0], np.where(clustering==1)[0])
                our_result = ncut.ncut_multigraph(subgraph, np.where(clustering==0)[0], np.where(clustering==1)[0])
                our_k_result = ncut.k_ncut_multigraph(subgraph,  np.asarray([np.where(clustering==0)[0], np.where(clustering==1)[0]]))

                if abs(our_result - nx_result) > precision or \
                    abs(our_k_result - nx_result) > precision or \
                    abs(our_result - nx_result) > precision:
                        
                    identical = False
                    break
        
        else:
            continue
        
        break

print(f"\nOur results were{' ' if identical else ' not '}identical to those of networkx for {n_checks} random partitions.")
# Out:
# Checking random partition no. 0
# Checking random partition no. 1
# Checking random partition no. 2
#
# Our results were identical to those of networkx for 3 random partitions.

# %%
# TODO: can k-way n-cut be validated?

# %% [markdown]
# ## Clustering the data

# %%
def ncut_by_k_partition(graph, partition):
    """Helper function to generate the right input structure for ncut.k_ncut_multigraph"""
    node_lists = np.asarray([np.where(partition == value)[0] for value in np.unique(partition)], dtype=object)
    return ncut.k_ncut_multigraph(graph, node_lists)

# %%
n_clusters = range(2, 20)

kmeans_ncut_results = []

for n in n_clusters:
    kmeans = KMeans(n_clusters=n)
    clustering1 = kmeans.fit_predict(g1_embedding)
    clustering2 = kmeans.fit_predict(g2_embedding)
    g1_ncut = ncut_by_k_partition(G1, clustering1)
    g2_ncut = ncut_by_k_partition(G2, clustering2)
    kmeans_ncut_results.append((f"KMeans n_clusters={n}", g1_ncut, g2_ncut, clustering1, clustering2))
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\micha\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
for result in kmeans_ncut_results:
    print(result[:3])
# Out:
# ['KMeans n_clusters=2', 0.4485409889722306, 0.498379984310383]
# ['KMeans n_clusters=3', 1.3399197916131274, 1.2944462057863382]
# ['KMeans n_clusters=4', 2.1215486648586985, 2.1137986243712095]
# ['KMeans n_clusters=5', 2.9859190897200683, 3.079176096322284]
# ['KMeans n_clusters=6', 3.634422312611997, 3.884316713956717]
# ['KMeans n_clusters=7', 4.632569146037368, 4.5416728549395184]
# ['KMeans n_clusters=8', 5.496837731714178, 5.521943274089302]
# ['KMeans n_clusters=9', 6.226891767906996, 6.219804957743332]
# ['KMeans n_clusters=10', 7.161083353918293, 7.054304999324301]
# ['KMeans n_clusters=11', 7.837647459218032, 7.860814147953587]
# ['KMeans n_clusters=12', 9.047207938056133, 8.866227577254483]
# ['KMeans n_clusters=13', 9.917331654927624, 9.809235599976638]
# ['KMeans n_clusters=14', 10.751564998163332, 10.47946332646856]
# ['KMeans n_clusters=15', 11.652609343170829, 11.658236301308582]
# ['KMeans n_clusters=16', 12.434447184086153, 12.641675954108846]
# ['KMeans n_clusters=17', 13.7477325255855, 13.672817274885434]
# ['KMeans n_clusters=18', 14.672115593381696, 14.69470943416906]
# ['KMeans n_clusters=19', 15.349092803243579, 15.42443546723027]

# %%
# trying to normalize the k-way n-cut values but unfortunately they are still dependent on k
for k, result in zip(range(2,20), kmeans_ncut_results):
    print(result[0], result[1]/k, result[2]/k)
# Out:
# KMeans n_clusters=2 0.2190331784808045 0.2491899921551915
# KMeans n_clusters=3 0.4466399305377091 0.4314820685954461
# KMeans n_clusters=4 0.5327627435080453 0.5299468462457981
# KMeans n_clusters=5 0.5971838179440137 0.6097142630575052
# KMeans n_clusters=6 0.6057370521019995 0.6429945638088416
# KMeans n_clusters=7 0.6684814095239136 0.6682259231924925
# KMeans n_clusters=8 0.685191389509136 0.6751290589498281
# KMeans n_clusters=9 0.7170270066630889 0.698642955779273
# KMeans n_clusters=10 0.7244285186115353 0.6893554928126029
# KMeans n_clusters=11 0.7201991856771871 0.713252864757272
# KMeans n_clusters=12 0.7484348828596153 0.7358706762762037
# KMeans n_clusters=13 0.7423614726513368 0.752878838460643
# KMeans n_clusters=14 0.7818792405468101 0.7684656786237857
# KMeans n_clusters=15 0.796374291535088 0.7738154165677261
# KMeans n_clusters=16 0.7884146540372925 0.7879570935427954
# KMeans n_clusters=17 0.8051191989996509 0.7954961941308769
# KMeans n_clusters=18 0.7980294360512756 0.7969424624667484
# KMeans n_clusters=19 0.8170491820744646 0.8129704124969173

# %% [markdown]
# ## Comparison of partitions

# %% [markdown]
# ### Comparison of NCut-values
# The NCut-values of the clusterings are slightly higher for the first graph.

# %%
kmeans_ncut_results = [list(res) for res in kmeans_ncut_results]
result_diffs = np.asarray([res[1] - res[2] for res in kmeans_ncut_results])
describe(result_diffs)
# Out:
# DescribeResult(nobs=18, minmax=(-0.24989440134471996, 0.27210167169477195), mean=0.007890197388166173, variance=0.015809939366866473, skewness=-0.07480597868178945, kurtosis=0.17981444223901777)

# %% [markdown]
# ### NMI scores
# Compares how similar clusterings on G1 and G2 are by calculating the NMIs between them.

# %%
descriptions = [res[0] for res in kmeans_ncut_results]

kmeans_nmis = [normalized_mutual_info_score(res[3], res[4]) for res in kmeans_ncut_results]
for res, nmi in zip(descriptions, kmeans_nmis):
    print(f"{res} NMI: {nmi}")
# Out:
# KMeans n_clusters=2 NMI: 0.6780944524398715
# KMeans n_clusters=3 NMI: 0.7770279988463308
# KMeans n_clusters=4 NMI: 0.6211129844846613
# KMeans n_clusters=5 NMI: 0.6459250898095461
# KMeans n_clusters=6 NMI: 0.6314509337316279
# KMeans n_clusters=7 NMI: 0.6007823791751202
# KMeans n_clusters=8 NMI: 0.5717101462657753
# KMeans n_clusters=9 NMI: 0.5803142275434278
# KMeans n_clusters=10 NMI: 0.6275796450143148
# KMeans n_clusters=11 NMI: 0.6714511045930431
# KMeans n_clusters=12 NMI: 0.696451333839114
# KMeans n_clusters=13 NMI: 0.7040097608999505
# KMeans n_clusters=14 NMI: 0.7234409610364316
# KMeans n_clusters=15 NMI: 0.6856745429784306
# KMeans n_clusters=16 NMI: 0.6703675924936925
# KMeans n_clusters=17 NMI: 0.6628729342936095
# KMeans n_clusters=18 NMI: 0.6504914037107836
# KMeans n_clusters=19 NMI: 0.7066365903066771

# %% [markdown]
# ### Comparison by attributes in clinical.csv
# In this section we investigate whether the attributes in clinical.csv (such as the age) have an influence on the NCut values of the partitions. To do that, we interpret the column values of clinical.csv as cluster labels, and compute the NCut valus of the graph layers (i.e. the patients) individually. Afterwards, we group the NCut values by cluster labels and compare descriptive statistics between the groups.

# %%
comparison_attributes = [
    ['sex', clinical_csv['SEX']],
    ['age over 50', clinical_csv['AGE'] > 50],
    ['BMI over 25', clinical_csv['BMI'] > 25],
    ['MS type', clinical_csv['MS_TYPE']],
    ['therapy', clinical_csv['THERAPY']]
]

# %%
# takes a while to run

individual_ncuts = []

for res in kmeans_ncut_results:
    
    G1_ncuts = []
    G1_partition = res[3]
    for patient in G1s:
        G1_ncuts.append(ncut_by_k_partition(patient, G1_partition))

    G2_ncuts = []
    G2_partition = res[4]
    for patient in G2s:
        G2_ncuts.append(ncut_by_k_partition(patient, G2_partition))
        
    individual_ncuts.append([res[0], G1_ncuts, G2_ncuts])

# %%
attribute_statistics = []

for part_description, G1_ncuts, G2_ncuts in individual_ncuts:
    for comp_description, labels in comparison_attributes:
        
        label_ncuts_g1 = {}
        label_ncuts_g2 = {}
        
        for label in np.unique(labels):
            indices = np.where(labels == label)[0]
            
            # note: if desired, more descriptive statistics could be saved here
            stats = describe(np.asarray(G1_ncuts)[indices])
            label_ncuts_g1[label] = {'mean': stats.mean, 'variance': stats.variance}
            
            stats = describe(np.asarray(G2_ncuts)[indices])
            label_ncuts_g2[label] = {'mean': stats.mean, 'variance': stats.variance}
            
        attribute_statistics.append({'partition_name' : part_description, 'attribute_name' : comp_description,
                                    'G1' : label_ncuts_g1, 'G2' : label_ncuts_g2})

# %%
for entry in attribute_statistics:
    
    print("Partition:", entry['partition_name'])
    print("Attribute:", entry['attribute_name'], "\n")
    
    for key in entry['G1'].keys():
        print(key)
        print("G1 mean ncut:", entry['G1'][key]['mean'])
        print("G2 mean ncut:", entry['G2'][key]['mean'])
        print()
        
    print("-------------------")
# Out:
# Partition: KMeans n_clusters=2
# Attribute: sex
#
# F
# G1 mean ncut: 0.44666108655689596
# G2 mean ncut: 0.5045774425620273
#
# M
# G1 mean ncut: 0.42536134258475505
# G2 mean ncut: 0.483686714324778
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: age over 50
#
# False
# G1 mean ncut: 0.43628292896835297
# G2 mean ncut: 0.5049785283882371
#
# True
# G1 mean ncut: 0.4413904421973277
# G2 mean ncut: 0.4855726861178785
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 0.4428168093559048
# G2 mean ncut: 0.5086785707632295
#
# True
# G1 mean ncut: 0.43103328756955167
# G2 mean ncut: 0.4756533688755535
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 0.44234057280040023
# G2 mean ncut: 0.45672633228023773
#
# relapsing_remitting
# G1 mean ncut: 0.42996563080729894
# G2 mean ncut: 0.4949442755822466
#
# secondary_progressive
# G1 mean ncut: 0.45184480989019776
# G2 mean ncut: 0.5112848220393547
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 0.44056838087736216
# G2 mean ncut: 0.5044812888188805
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 0.429631203714525
# G2 mean ncut: 0.5014193051081834
#
# Vojta_reflex_locomotion
# G1 mean ncut: 0.4596093234119202
# G2 mean ncut: 0.4759728212262479
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: sex
#
# F
# G1 mean ncut: 1.340638133876614
# G2 mean ncut: 1.3034914584312203
#
# M
# G1 mean ncut: 1.306766468132667
# G2 mean ncut: 1.2675256745143668
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: age over 50
#
# False
# G1 mean ncut: 1.336347314066446
# G2 mean ncut: 1.2964786546563831
#
# True
# G1 mean ncut: 1.3162858093164187
# G2 mean ncut: 1.2808461622103289
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 1.3326637760780358
# G2 mean ncut: 1.3011414861804809
#
# True
# G1 mean ncut: 1.3190007377054866
# G2 mean ncut: 1.2699499091330597
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 1.3149803623302663
# G2 mean ncut: 1.2436963070802134
#
# relapsing_remitting
# G1 mean ncut: 1.3174360527815105
# G2 mean ncut: 1.2888174644137456
#
# secondary_progressive
# G1 mean ncut: 1.348826587596655
# G2 mean ncut: 1.3050151421618472
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 1.3530941173934796
# G2 mean ncut: 1.2779045527693749
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 1.312422904715735
# G2 mean ncut: 1.2999955918690738
#
# Vojta_reflex_locomotion
# G1 mean ncut: 1.3420490333873727
# G2 mean ncut: 1.2745896281719384
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: sex
#
# F
# G1 mean ncut: 2.1021532417637956
# G2 mean ncut: 2.129464282022319
#
# M
# G1 mean ncut: 2.0144974548645442
# G2 mean ncut: 2.075213092000809
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: age over 50
#
# False
# G1 mean ncut: 2.1178817864451878
# G2 mean ncut: 2.110171659476553
#
# True
# G1 mean ncut: 2.0040434872310984
# G2 mean ncut: 2.1067016587939067
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 2.078360662292948
# G2 mean ncut: 2.1063318938349656
#
# True
# G1 mean ncut: 2.051609374546041
# G2 mean ncut: 2.112703072050714
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 2.0277766647109283
# G2 mean ncut: 2.0412604054408914
#
# relapsing_remitting
# G1 mean ncut: 2.1029086617124295
# G2 mean ncut: 2.1090577374091843
#
# secondary_progressive
# G1 mean ncut: 2.0223778460328385
# G2 mean ncut: 2.128227702314338
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 2.1317662177257777
# G2 mean ncut: 2.0888500987889804
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 2.034330381393058
# G2 mean ncut: 2.1276278098100163
#
# Vojta_reflex_locomotion
# G1 mean ncut: 2.0948398161035278
# G2 mean ncut: 2.0788986717728544
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: sex
#
# F
# G1 mean ncut: 2.9542878599862408
# G2 mean ncut: 3.0390799354792297
#
# M
# G1 mean ncut: 2.858249750802419
# G2 mean ncut: 2.9795538149034213
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: age over 50
#
# False
# G1 mean ncut: 2.96955519912878
# G2 mean ncut: 2.9837999539337363
#
# True
# G1 mean ncut: 2.849366089137232
# G2 mean ncut: 3.058711420067814
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 2.932941675591041
# G2 mean ncut: 3.033130438411785
#
# True
# G1 mean ncut: 2.8907550643403175
# G2 mean ncut: 2.9871244861755626
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 2.8628064464201812
# G2 mean ncut: 3.027525852866184
#
# relapsing_remitting
# G1 mean ncut: 2.955604958891774
# G2 mean ncut: 2.9675243848724104
#
# secondary_progressive
# G1 mean ncut: 2.8690493903552574
# G2 mean ncut: 3.0957355576325565
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 2.990904924644578
# G2 mean ncut: 3.0530599481107945
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 2.8884003057135623
# G2 mean ncut: 3.070778811413002
#
# Vojta_reflex_locomotion
# G1 mean ncut: 2.920078513331225
# G2 mean ncut: 2.8368797263098307
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: sex
#
# F
# G1 mean ncut: 3.6096193023268954
# G2 mean ncut: 3.829928050296263
#
# M
# G1 mean ncut: 3.4606756144529043
# G2 mean ncut: 3.7839444146756764
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: age over 50
#
# False
# G1 mean ncut: 3.612296126579441
# G2 mean ncut: 3.7764184065328132
#
# True
# G1 mean ncut: 3.474360962108113
# G2 mean ncut: 3.8592243683225624
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 3.5600674646443493
# G2 mean ncut: 3.826643670738137
#
# True
# G1 mean ncut: 3.539494984637574
# G2 mean ncut: 3.7875272686569574
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 3.5526150511418493
# G2 mean ncut: 3.89108888400283
#
# relapsing_remitting
# G1 mean ncut: 3.5860205865789605
# G2 mean ncut: 3.7618431325930466
#
# secondary_progressive
# G1 mean ncut: 3.4955531533988085
# G2 mean ncut: 3.8744429793160875
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 3.590755999987707
# G2 mean ncut: 3.865276260441836
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 3.5354200950988517
# G2 mean ncut: 3.8788882262159063
#
# Vojta_reflex_locomotion
# G1 mean ncut: 3.559026314254676
# G2 mean ncut: 3.585174486262891
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: sex
#
# F
# G1 mean ncut: 4.597142977349492
# G2 mean ncut: 4.405012589627199
#
# M
# G1 mean ncut: 4.458923088394233
# G2 mean ncut: 4.452447687186226
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: age over 50
#
# False
# G1 mean ncut: 4.583607401334797
# G2 mean ncut: 4.399555291633474
#
# True
# G1 mean ncut: 4.492571905754439
# G2 mean ncut: 4.454110873305827
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 4.5569333414906925
# G2 mean ncut: 4.4298548680758
#
# True
# G1 mean ncut: 4.522093373561466
# G2 mean ncut: 4.411694437936779
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 4.570133325154732
# G2 mean ncut: 4.537036312730869
#
# relapsing_remitting
# G1 mean ncut: 4.551790574268629
# G2 mean ncut: 4.364609270223137
#
# secondary_progressive
# G1 mean ncut: 4.523392085946838
# G2 mean ncut: 4.488641477875885
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 4.601043296857055
# G2 mean ncut: 4.534091633570413
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 4.528607714063725
# G2 mean ncut: 4.473447494765969
#
# Vojta_reflex_locomotion
# G1 mean ncut: 4.527945850591555
# G2 mean ncut: 4.180873581771639
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: sex
#
# F
# G1 mean ncut: 5.45507335825443
# G2 mean ncut: 5.435291411024873
#
# M
# G1 mean ncut: 5.290381718932382
# G2 mean ncut: 5.398502225760651
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: age over 50
#
# False
# G1 mean ncut: 5.430533648726193
# G2 mean ncut: 5.378134132837906
#
# True
# G1 mean ncut: 5.341474989775699
# G2 mean ncut: 5.4774912647664005
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 5.4008684804985805
# G2 mean ncut: 5.423743964252028
#
# True
# G1 mean ncut: 5.37652234235967
# G2 mean ncut: 5.416775579947191
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 5.3920001406822164
# G2 mean ncut: 5.514974683937389
#
# relapsing_remitting
# G1 mean ncut: 5.394049562600067
# G2 mean ncut: 5.362975427850616
#
# secondary_progressive
# G1 mean ncut: 5.388340390918158
# G2 mean ncut: 5.4920160374934985
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 5.458411289760714
# G2 mean ncut: 5.486830955443982
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 5.38282618705219
# G2 mean ncut: 5.46440771995948
#
# Vojta_reflex_locomotion
# G1 mean ncut: 5.349312051091924
# G2 mean ncut: 5.242512961617013
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: sex
#
# F
# G1 mean ncut: 6.159196276125983
# G2 mean ncut: 6.025144858169966
#
# M
# G1 mean ncut: 6.003257111882363
# G2 mean ncut: 6.057588973625858
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: age over 50
#
# False
# G1 mean ncut: 6.111062326947426
# G2 mean ncut: 6.003308390661393
#
# True
# G1 mean ncut: 6.084194487451664
# G2 mean ncut: 6.082400802430621
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 6.085825377556412
# G2 mean ncut: 6.032162642653852
#
# True
# G1 mean ncut: 6.122900520127823
# G2 mean ncut: 6.046942078401686
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 6.141288016850493
# G2 mean ncut: 6.230289622168307
#
# relapsing_remitting
# G1 mean ncut: 6.089395218833013
# G2 mean ncut: 5.9646853599528225
#
# secondary_progressive
# G1 mean ncut: 6.103900512426518
# G2 mean ncut: 6.103693308713883
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 6.172341488823279
# G2 mean ncut: 6.166522680529723
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 6.086874082661813
# G2 mean ncut: 6.102510441932663
#
# Vojta_reflex_locomotion
# G1 mean ncut: 6.059309048057804
# G2 mean ncut: 5.738827405622043
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: sex
#
# F
# G1 mean ncut: 7.09359583050963
# G2 mean ncut: 6.877117540025656
#
# M
# G1 mean ncut: 6.938949629163075
# G2 mean ncut: 6.8779843228024085
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: age over 50
#
# False
# G1 mean ncut: 7.051384180892319
# G2 mean ncut: 6.821708049067173
#
# True
# G1 mean ncut: 7.011993271125697
# G2 mean ncut: 6.9503428745046465
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 7.02308213704301
# G2 mean ncut: 6.88004887572589
#
# True
# G1 mean ncut: 7.053716635998755
# G2 mean ncut: 6.872960505810039
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 7.148861661180159
# G2 mean ncut: 7.017596505522021
#
# relapsing_remitting
# G1 mean ncut: 7.002137638617657
# G2 mean ncut: 6.8011547017894145
#
# secondary_progressive
# G1 mean ncut: 7.054651875976286
# G2 mean ncut: 6.965107475571623
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 7.0975817917607555
# G2 mean ncut: 7.066481865610756
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 7.02945207338858
# G2 mean ncut: 6.922414493138713
#
# Vojta_reflex_locomotion
# G1 mean ncut: 6.98376564703888
# G2 mean ncut: 6.570817798903736
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: sex
#
# F
# G1 mean ncut: 7.7452440539298575
# G2 mean ncut: 7.684302100160117
#
# M
# G1 mean ncut: 7.55171988580186
# G2 mean ncut: 7.67948353938239
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: age over 50
#
# False
# G1 mean ncut: 7.664296236939919
# G2 mean ncut: 7.611016189236928
#
# True
# G1 mean ncut: 7.6799044351111645
# G2 mean ncut: 7.775874949140913
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 7.655771484462084
# G2 mean ncut: 7.687255907328394
#
# True
# G1 mean ncut: 7.697466861785831
# G2 mean ncut: 7.674162483329106
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 7.823787734968833
# G2 mean ncut: 7.777626050540896
#
# relapsing_remitting
# G1 mean ncut: 7.601358960334767
# G2 mean ncut: 7.618868984536403
#
# secondary_progressive
# G1 mean ncut: 7.743732815382623
# G2 mean ncut: 7.761999866711809
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 7.692142886289791
# G2 mean ncut: 7.877141527971383
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 7.704295043744018
# G2 mean ncut: 7.718536182112247
#
# Vojta_reflex_locomotion
# G1 mean ncut: 7.563053719983354
# G2 mean ncut: 7.39340223509807
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: sex
#
# F
# G1 mean ncut: 8.9574571992855
# G2 mean ncut: 8.671296702946242
#
# M
# G1 mean ncut: 8.781701357719086
# G2 mean ncut: 8.703762313306585
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: age over 50
#
# False
# G1 mean ncut: 8.906445776444542
# G2 mean ncut: 8.626427549546348
#
# True
# G1 mean ncut: 8.868688123153389
# G2 mean ncut: 8.758691328095635
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 8.87944881278703
# G2 mean ncut: 8.672453389659763
#
# True
# G1 mean ncut: 8.908454214327064
# G2 mean ncut: 8.70324010945415
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 8.947465795445595
# G2 mean ncut: 8.869664598900437
#
# relapsing_remitting
# G1 mean ncut: 8.876411851028625
# G2 mean ncut: 8.601676204798686
#
# secondary_progressive
# G1 mean ncut: 8.896112494672785
# G2 mean ncut: 8.76747663292522
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 8.95071253181902
# G2 mean ncut: 8.853124956865434
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 8.883963288960189
# G2 mean ncut: 8.731274705020079
#
# Vojta_reflex_locomotion
# G1 mean ncut: 8.845464066369912
# G2 mean ncut: 8.390042061933002
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: sex
#
# F
# G1 mean ncut: 9.800930001883136
# G2 mean ncut: 9.607659753045306
#
# M
# G1 mean ncut: 9.6060240559019
# G2 mean ncut: 9.615243214587402
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: age over 50
#
# False
# G1 mean ncut: 9.71503932651963
# G2 mean ncut: 9.53492108817047
#
# True
# G1 mean ncut: 9.740831778990469
# G2 mean ncut: 9.709487992322712
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 9.699013874560656
# G2 mean ncut: 9.595741736320205
#
# True
# G1 mean ncut: 9.77320164191431
# G2 mean ncut: 9.636173582637216
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 9.856940971680801
# G2 mean ncut: 9.819690656547335
#
# relapsing_remitting
# G1 mean ncut: 9.68410421922807
# G2 mean ncut: 9.539512445650718
#
# secondary_progressive
# G1 mean ncut: 9.758588703579024
# G2 mean ncut: 9.668621885338904
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 9.779539223810149
# G2 mean ncut: 9.784928426880024
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 9.727198404882719
# G2 mean ncut: 9.651946074053185
#
# Vojta_reflex_locomotion
# G1 mean ncut: 9.67032366768272
# G2 mean ncut: 9.327982210072143
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: sex
#
# F
# G1 mean ncut: 10.57866202520605
# G2 mean ncut: 10.210376357450462
#
# M
# G1 mean ncut: 10.463303918702437
# G2 mean ncut: 10.244375468799124
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: age over 50
#
# False
# G1 mean ncut: 10.542959602608589
# G2 mean ncut: 10.170601990606803
#
# True
# G1 mean ncut: 10.52330225284953
# G2 mean ncut: 10.292465127977525
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 10.558872265322876
# G2 mean ncut: 10.17500352198028
#
# True
# G1 mean ncut: 10.4922426809323
# G2 mean ncut: 10.30701941694529
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 10.731879502433713
# G2 mean ncut: 10.428850022586548
#
# relapsing_remitting
# G1 mean ncut: 10.4728902332789
# G2 mean ncut: 10.176806605609602
#
# secondary_progressive
# G1 mean ncut: 10.579847005834754
# G2 mean ncut: 10.241001814090064
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 10.584030625453494
# G2 mean ncut: 10.422386108417424
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 10.573551927703711
# G2 mean ncut: 10.247184422762697
#
# Vojta_reflex_locomotion
# G1 mean ncut: 10.382563183842944
# G2 mean ncut: 9.962251632668373
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: sex
#
# F
# G1 mean ncut: 11.456102393200245
# G2 mean ncut: 11.326069665061532
#
# M
# G1 mean ncut: 11.315112220159108
# G2 mean ncut: 11.237537330932723
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: age over 50
#
# False
# G1 mean ncut: 11.375711302949565
# G2 mean ncut: 11.205501101945584
#
# True
# G1 mean ncut: 11.436507127376286
# G2 mean ncut: 11.405419182791515
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 11.404458350929884
# G2 mean ncut: 11.270037485461708
#
# True
# G1 mean ncut: 11.39790692166968
# G2 mean ncut: 11.330295989599284
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 11.652507089229772
# G2 mean ncut: 11.37797282908756
#
# relapsing_remitting
# G1 mean ncut: 11.326402038001355
# G2 mean ncut: 11.246153252841143
#
# secondary_progressive
# G1 mean ncut: 11.455532889232199
# G2 mean ncut: 11.344544432380252
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 11.439098757383402
# G2 mean ncut: 11.512747567187319
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 11.432455319065625
# G2 mean ncut: 11.305473704735352
#
# Vojta_reflex_locomotion
# G1 mean ncut: 11.285508070604088
# G2 mean ncut: 11.036623991099397
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: sex
#
# F
# G1 mean ncut: 12.123199873728812
# G2 mean ncut: 12.384910361258056
#
# M
# G1 mean ncut: 11.977492932173126
# G2 mean ncut: 12.4171401190704
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: age over 50
#
# False
# G1 mean ncut: 12.060377980684223
# G2 mean ncut: 12.30499541331925
#
# True
# G1 mean ncut: 12.076456977872475
# G2 mean ncut: 12.51792546355049
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 12.026590429440136
# G2 mean ncut: 12.3829763031211
#
# True
# G1 mean ncut: 12.137740747691943
# G2 mean ncut: 12.421945753934796
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 12.24138011329601
# G2 mean ncut: 12.70004793920805
#
# relapsing_remitting
# G1 mean ncut: 12.026802935126284
# G2 mean ncut: 12.287699827801712
#
# secondary_progressive
# G1 mean ncut: 12.084057614693913
# G2 mean ncut: 12.49269121623304
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 12.139674099428753
# G2 mean ncut: 12.682543944338109
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 12.057232775124115
# G2 mean ncut: 12.454326612666009
#
# Vojta_reflex_locomotion
# G1 mean ncut: 12.021465778550326
# G2 mean ncut: 11.96274846139443
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: sex
#
# F
# G1 mean ncut: 13.55287576270575
# G2 mean ncut: 13.400432229461062
#
# M
# G1 mean ncut: 13.372761262387838
# G2 mean ncut: 13.48604705787433
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: age over 50
#
# False
# G1 mean ncut: 13.516241245713147
# G2 mean ncut: 13.350877087261924
#
# True
# G1 mean ncut: 13.441450380799463
# G2 mean ncut: 13.540971302087058
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 13.486950846805707
# G2 mean ncut: 13.39494362365843
#
# True
# G1 mean ncut: 13.478444548928008
# G2 mean ncut: 13.49941896009766
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 13.496237491423528
# G2 mean ncut: 13.724797988783223
#
# relapsing_remitting
# G1 mean ncut: 13.506827810625738
# G2 mean ncut: 13.340039391392798
#
# secondary_progressive
# G1 mean ncut: 13.441017087260837
# G2 mean ncut: 13.504247379055727
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 13.505415891361274
# G2 mean ncut: 13.636618574842286
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 13.494080541290904
# G2 mean ncut: 13.486280461955253
#
# Vojta_reflex_locomotion
# G1 mean ncut: 13.435443635649666
# G2 mean ncut: 13.091192126287739
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: sex
#
# F
# G1 mean ncut: 14.43465444444546
# G2 mean ncut: 14.482828396585893
#
# M
# G1 mean ncut: 14.279466940927927
# G2 mean ncut: 14.435124515279218
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: age over 50
#
# False
# G1 mean ncut: 14.404115449603239
# G2 mean ncut: 14.401211605099025
#
# True
# G1 mean ncut: 14.337308799973624
# G2 mean ncut: 14.547358459682052
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 14.354702580525492
# G2 mean ncut: 14.43943500117175
#
# True
# G1 mean ncut: 14.4105116375389
# G2 mean ncut: 14.507908385480624
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 14.469721381961065
# G2 mean ncut: 14.645292409430398
#
# relapsing_remitting
# G1 mean ncut: 14.403080864596655
# G2 mean ncut: 14.391640674790175
#
# secondary_progressive
# G1 mean ncut: 14.299343819888586
# G2 mean ncut: 14.534248856282591
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 14.397497916499677
# G2 mean ncut: 14.669685355730666
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 14.358295161756283
# G2 mean ncut: 14.505101596016992
#
# Vojta_reflex_locomotion
# G1 mean ncut: 14.396957359354994
# G2 mean ncut: 14.153319279694141
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: sex
#
# F
# G1 mean ncut: 14.965167428302337
# G2 mean ncut: 15.019764935619264
#
# M
# G1 mean ncut: 14.878183492374927
# G2 mean ncut: 14.929121679880472
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: age over 50
#
# False
# G1 mean ncut: 14.94652552205708
# G2 mean ncut: 14.906229848811337
#
# True
# G1 mean ncut: 14.912597977764193
# G2 mean ncut: 15.088049476753014
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 14.929184439647647
# G2 mean ncut: 14.913706746584904
#
# True
# G1 mean ncut: 14.93638211205451
# G2 mean ncut: 15.108192949315344
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 15.06020584327573
# G2 mean ncut: 15.0796354184685
#
# relapsing_remitting
# G1 mean ncut: 14.892361930429274
# G2 mean ncut: 14.95620246978037
#
# secondary_progressive
# G1 mean ncut: 14.960393723878
# G2 mean ncut: 15.00562023859101
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 14.962872294699308
# G2 mean ncut: 15.163121225379522
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 14.913956809389667
# G2 mean ncut: 14.959774352703603
#
# Vojta_reflex_locomotion
# G1 mean ncut: 14.947503370882298
# G2 mean ncut: 14.872938256408272
#
# -------------------

# %% [markdown]
# Comparing the mean NCuts for n_clusters=2 between patients of different ages, it seems that patients under 51 years have a lower average ncut value than those over 50 in graph 1, but a higher average ncut value in graph 2. A higher ncut value means that the partitions are more similar to each other. Based on this result, we can speculate that ???\
# **insert more analysis here**

# %% [markdown]
# # Task 2d
