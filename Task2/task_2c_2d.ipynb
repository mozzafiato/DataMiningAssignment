# %% [markdown]
# # Task 2c

# %%
import torch
import os
import networkx as nx
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score
from scipy.stats import describe
import ncut
from itertools import product

# %% [markdown]
# ### Loading the graphs

# %% [markdown]
# Graph loading functions, could be changed to load multigraph directly from file

# %%
def csv_to_graph(path, threshold=0.3):
    # load in csv as dataframe
    df = pd.read_csv(path,header=None)
    
    # threshold dataframe and remove diagonal
    A = (df>threshold).astype(int) - pd.DataFrame(np.identity(df.shape[0]))
         
    # convert to graph
    G = nx.from_pandas_adjacency(A)
    
    return G

def load_graphs(folder):
    #load in all graphs in folder
    G1s, G2s = [],[]

    for i in range(1,61):
        filename = f'{folder}/p{i:03}_1.csv'
        G1s.append(csv_to_graph(filename))

        filename = f'{folder}/p{i:03}_2.csv'
        G2s.append(csv_to_graph(filename))
        
    return G1s, G2s

G1s, G2s = load_graphs("FC")

# %%
def graph_list_to_multigraph(graphs):
    G = nx.MultiGraph()
    for subgraph in graphs:
        G.add_nodes_from(subgraph.nodes)
        G.add_edges_from(subgraph.edges)
    return G

# %%
G1 = graph_list_to_multigraph(G1s)
G2 = graph_list_to_multigraph(G2s)

# %% [markdown]
# ### Loading the embeddings

# %%
EMBEDDING_DIR = "embedding_pickles"
G1_PATH = "best_G1_DMGI.pkl"
G2_PATH = "best_G2_DMGI.pkl"

# %%
g1_model = torch.load(os.path.join(EMBEDDING_DIR, G1_PATH))
g1_embedding = g1_model['H'].squeeze()

g2_model = torch.load(os.path.join(EMBEDDING_DIR, G2_PATH))
g2_embedding = g2_model['H'].squeeze()

# %% [markdown]
# ### Loading additional clinical data

# %%
clinical_csv = pd.read_csv("clinical.csv")
clinical_csv
# Out:
#       ID SEX                MS_TYPE  AGE  EDSS  DATASET  DIAG_YEARS     BMI  \
# 0   p001   M    primary_progressive   40     7        2          11  19.918
# 1   p002   M  secondary_progressive   44     7        2          17  20.529
# 2   p003   M    primary_progressive   51     6        2          21  25.249
# 3   p004   M    relapsing_remitting   29     3        2           9  21.500
# 4   p005   F  secondary_progressive   60     6        2          21  21.411
# 5   p006   M  secondary_progressive   68     4        2           7  21.605
# 6   p007   F    relapsing_remitting   36     4        2           9  19.370
# 7   p008   F    relapsing_remitting   32     4        2           4  19.141
# 8   p009   F    relapsing_remitting   35     4        1          20  16.436
# 9   p010   M  secondary_progressive   54     6        2          12  23.148
# 10  p011   M    relapsing_remitting   45     6        2          15  24.516
# 11  p012   M    relapsing_remitting   39     2        2          12  18.937
# 12  p013   F    relapsing_remitting   58     4        2          13  25.510
# 13  p014   M    primary_progressive   42     4        2           8  21.267
# 14  p015   F    relapsing_remitting   44     2        2          14  27.885
# 15  p016   M    relapsing_remitting   43     2        2          18  25.249
# 16  p017   M    relapsing_remitting   43     3        2          11  20.831
# 17  p018   F  secondary_progressive   53     5        2          17  35.380
# 18  p019   F  secondary_progressive   59     6        2          12  30.477
# 19  p020   F  secondary_progressive   58     4        2          19  20.833
# 20  p021   F  secondary_progressive   45     5        2          20  21.201
# 21  p022   M    relapsing_remitting   54     4        2          13  28.710
# 22  p023   M    primary_progressive   54     4        2           2  32.028
# 23  p024   F  secondary_progressive   38     5        2          17  22.656
# 24  p025   F  secondary_progressive   65     6        2          31  21.484
# 25  p026   M    relapsing_remitting   40     5        2          13  20.831
# 26  p027   F    relapsing_remitting   41     4        2           4  28.735
# 27  p028   F    relapsing_remitting   45     6        1           3  28.842
# 28  p029   F    relapsing_remitting   55     6        2          21  26.730
# 29  p030   M    relapsing_remitting   56     4        2           6  36.296
# 30  p031   F  secondary_progressive   56     5        2          14  21.755
# 31  p032   F    primary_progressive   59     4        2           4  26.573
# 32  p033   F    relapsing_remitting   39     5        1          15  18.145
# 33  p034   F    relapsing_remitting   22     1        1           1  21.107
# 34  p035   M  secondary_progressive   41     6        2           8  20.984
# 35  p036   F    relapsing_remitting   32     2        1           8  23.837
# 36  p037   M    relapsing_remitting   36     6        1          14  25.592
# 37  p038   F    relapsing_remitting   40     6        1          15  20.428
# 38  p039   F    relapsing_remitting   43     1        1          12  27.942
# 39  p040   F    relapsing_remitting   45     5        1          16  27.042
# 40  p041   F  secondary_progressive   35     5        1           8  21.830
# 41  p042   M    relapsing_remitting   40     2        1           9  19.818
# 42  p043   F    relapsing_remitting   50     3        1          10  22.137
# 43  p044   F  secondary_progressive   48     5        1          23  22.833
# 44  p045   M    relapsing_remitting   39     4        1          11  31.699
# 45  p046   F  secondary_progressive   63     4        1           3  23.809
# 46  p047   F  secondary_progressive   63     6        1          38  22.039
# 47  p048   F    relapsing_remitting   61     3        1          13  20.576
# 48  p049   F  secondary_progressive   58     4        1           4  33.802
# 49  p050   M    primary_progressive   53     1        1           1  24.057
# 50  p051   F  secondary_progressive   61     4        1           9  25.014
# 51  p052   M    relapsing_remitting   53     4        1           7  25.952
# 52  p053   F    relapsing_remitting   51     4        1          18  22.477
# 53  p054   M  secondary_progressive   63     6        1          22  21.701
# 54  p055   F  secondary_progressive   70     4        1          10  20.701
# 55  p056   F    relapsing_remitting   67     3        1          22  29.001
# 56  p057   M    relapsing_remitting   50     6        1          11  24.691
# 57  p058   F    relapsing_remitting   47     6        1          17  24.447
# 58  p059   F    relapsing_remitting   29     3        2           9  20.904
# 59  p060   F    relapsing_remitting   38     2        1          11  25.654
#
#                              THERAPY  outliers_V1  outliers_V2
# 0    Functional_electric_stimulation            0           14
# 1   Motor_Program_Activating_Therapy            4            0
# 2    Functional_electric_stimulation            4            0
# 3    Functional_electric_stimulation            4            2
# 4    Functional_electric_stimulation            0            4
# 5   Motor_Program_Activating_Therapy            2            3
# 6    Functional_electric_stimulation            6            7
# 7    Functional_electric_stimulation            5            7
# 8   Motor_Program_Activating_Therapy            3            0
# 9   Motor_Program_Activating_Therapy           20            6
# 10   Functional_electric_stimulation            0            2
# 11  Motor_Program_Activating_Therapy            0            2
# 12  Motor_Program_Activating_Therapy           38           13
# 13  Motor_Program_Activating_Therapy            0            3
# 14  Motor_Program_Activating_Therapy            4            0
# 15   Functional_electric_stimulation            0            6
# 16   Functional_electric_stimulation            0            0
# 17   Functional_electric_stimulation            2            4
# 18  Motor_Program_Activating_Therapy            4           42
# 19   Functional_electric_stimulation            0            2
# 20  Motor_Program_Activating_Therapy            0            0
# 21  Motor_Program_Activating_Therapy            0            0
# 22   Functional_electric_stimulation           19            6
# 23  Motor_Program_Activating_Therapy            0            0
# 24  Motor_Program_Activating_Therapy            0            0
# 25  Motor_Program_Activating_Therapy            0            0
# 26  Motor_Program_Activating_Therapy            0            0
# 27           Vojta_reflex_locomotion            0            2
# 28  Motor_Program_Activating_Therapy            0            0
# 29  Motor_Program_Activating_Therapy            4            9
# 30   Functional_electric_stimulation            0            2
# 31  Motor_Program_Activating_Therapy            0            5
# 32           Vojta_reflex_locomotion            4            0
# 33           Vojta_reflex_locomotion            0            0
# 34  Motor_Program_Activating_Therapy           10           25
# 35           Vojta_reflex_locomotion            0            0
# 36           Vojta_reflex_locomotion            0            5
# 37           Vojta_reflex_locomotion            2            2
# 38  Motor_Program_Activating_Therapy            2            0
# 39  Motor_Program_Activating_Therapy           10           30
# 40  Motor_Program_Activating_Therapy            4            6
# 41           Vojta_reflex_locomotion            0            0
# 42  Motor_Program_Activating_Therapy            4            2
# 43  Motor_Program_Activating_Therapy            2            4
# 44           Vojta_reflex_locomotion            2            4
# 45           Vojta_reflex_locomotion            3            9
# 46  Motor_Program_Activating_Therapy           41           21
# 47  Motor_Program_Activating_Therapy            0            0
# 48  Motor_Program_Activating_Therapy            4            2
# 49           Vojta_reflex_locomotion            0            2
# 50  Motor_Program_Activating_Therapy            8            3
# 51           Vojta_reflex_locomotion            6            3
# 52  Motor_Program_Activating_Therapy            0            5
# 53  Motor_Program_Activating_Therapy            8            0
# 54  Motor_Program_Activating_Therapy            5            0
# 55  Motor_Program_Activating_Therapy            2           14
# 56           Vojta_reflex_locomotion            0            0
# 57  Motor_Program_Activating_Therapy            0            0
# 58  Motor_Program_Activating_Therapy            0            0
# 59           Vojta_reflex_locomotion            0            0

# %% [markdown]
# ## Validation of our NCut implementation
# Validates our implementation of NCut against networkx by comparing the NCut values of random binary graph partitions.

# %%
# binary partitions validation on multigraphs

identical = True
graphs = [G1, G2]

n_checks = 10
precision = 1e-10

for i in range(n_checks):
    
        # np.random.seed(150896)

        print(f"Checking random partition no. {i}")
        clustering = np.random.randint(0, 2, size=len(G1.nodes))
        
        nodes1 = np.where(clustering==0)[0]
        nodes2 = np.where(clustering==1)[0]

        for graph in graphs:
            nx_result = nx.normalized_cut_size(graph, nodes1, nodes2)
            our_result = ncut.ncut_multigraph(graph, nodes1, nodes2)
            our_k_result = ncut.k_ncut_multigraph(graph, np.asarray([nodes1, nodes2], dtype=object))
            
            if abs(our_result - nx_result) > precision or abs(our_k_result - nx_result) > precision:
                identical = False
                break
        
        else:
            continue
        
        break

print(f"\nOur results were{' ' if identical else ' not '}identical to those of networkx for {n_checks} random partitions.")
# Out:
# Checking random partition no. 0
# Checking random partition no. 1
# Checking random partition no. 2
# Checking random partition no. 3
# Checking random partition no. 4
# Checking random partition no. 5
# Checking random partition no. 6
# Checking random partition no. 7
# Checking random partition no. 8
# Checking random partition no. 9
#
# Our results were identical to those of networkx for 10 random partitions.

# %%
# binary partitions validation on single graphs

identical = True
graphs = [G1s, G2s]

n_checks = 10
precision = 1e-10

for i in range(n_checks):
    
        print(f"Checking random partition no. {i}")
        clustering = np.random.randint(0, 2, size=len(G1.nodes))
        
        for graph in graphs:
            for subgraph in graph:
                nx_result = nx.normalized_cut_size(subgraph, np.where(clustering==0)[0], np.where(clustering==1)[0])
                our_single_result = ncut.ncut_single_graph(subgraph, np.where(clustering==0)[0], np.where(clustering==1)[0])
                # our_result = ncut.ncut_multigraph(subgraph, np.where(clustering==0)[0], np.where(clustering==1)[0])
                our_k_result = ncut.k_ncut_multigraph(subgraph,  [np.where(clustering==0)[0], np.where(clustering==1)[0]])

                if abs(our_result - nx_result) > precision or \
                    abs(our_k_result - nx_result) > precision or \
                    abs(our_result - nx_result) > precision:
                        
                    identical = False
                    break
        
        else:
            continue
        
        break

print(f"\nOur results were{' ' if identical else ' not '}identical to those of networkx for {n_checks} random partitions.")
# Out:
# Checking random partition no. 0
# Checking random partition no. 1
# Checking random partition no. 2
# Checking random partition no. 3
# Checking random partition no. 4
# Checking random partition no. 5
# Checking random partition no. 6
# Checking random partition no. 7
# Checking random partition no. 8
# Checking random partition no. 9
#
# Our results were not identical to those of networkx for 10 random partitions.

# %%
# TODO: can k-way n-cut be validated?

# %% [markdown]
# ## Clustering the data

# %%
def ncut_by_k_partition(graph, partition):
    """Helper function to generate the right input structure for ncut.k_ncut_multigraph"""
    node_lists = np.asarray([np.where(partition == value)[0] for value in np.unique(partition)], dtype=object)
    return ncut.k_ncut_multigraph(graph, node_lists)

# %%
n_clusters = range(2, 20)

kmeans_ncut_results = []

for n in n_clusters:
    kmeans = KMeans(n_clusters=n, n_init=10)
    clustering1 = kmeans.fit_predict(g1_embedding)
    clustering2 = kmeans.fit_predict(g2_embedding)
    g1_ncut = ncut_by_k_partition(G1, clustering1)
    g2_ncut = ncut_by_k_partition(G2, clustering2)
    kmeans_ncut_results.append((f"KMeans n_clusters={n}", g1_ncut, g2_ncut, clustering1, clustering2))

# %%
for result in kmeans_ncut_results:
    print(result[:3])
# Out:
# ('KMeans n_clusters=2', 0.4485409889722306, 0.498379984310383)
# ('KMeans n_clusters=3', 1.3399197916131274, 1.2944462057863382)
# ('KMeans n_clusters=4', 2.1568309204141634, 2.113798624371209)
# ('KMeans n_clusters=5', 2.934989958947483, 3.0425825546755423)
# ('KMeans n_clusters=6', 3.6024664572557485, 3.8110486163501536)
# ('KMeans n_clusters=7', 4.640316018879102, 4.738647847777905)
# ('KMeans n_clusters=8', 5.480110573949453, 5.366073798047487)
# ('KMeans n_clusters=9', 6.495399307541367, 6.205974297522442)
# ('KMeans n_clusters=10', 7.0939501459122996, 7.174016291385115)
# ('KMeans n_clusters=11', 8.050592394875874, 7.83790119641572)
# ('KMeans n_clusters=12', 8.985809870643214, 9.005215928507635)
# ('KMeans n_clusters=13', 9.891679874930933, 9.930695637384751)
# ('KMeans n_clusters=14', 10.826646347424079, 10.764710572247543)
# ('KMeans n_clusters=15', 11.840386359039993, 11.643600475465641)
# ('KMeans n_clusters=16', 12.500359900406346, 12.770812818953472)
# ('KMeans n_clusters=17', 13.70670141404227, 13.605987344786234)
# ('KMeans n_clusters=18', 14.722335584195626, 14.441855436907714)
# ('KMeans n_clusters=19', 15.630840785585331, 15.388263736554755)

# %%
# trying to normalize the k-way n-cut values but unfortunately they are still dependent on k
for k, result in zip(range(2,20), kmeans_ncut_results):
    print(result[0], result[1]/k, result[2]/k)
# Out:
# KMeans n_clusters=2 0.2242704944861153 0.2491899921551915
# KMeans n_clusters=3 0.4466399305377091 0.4314820685954461
# KMeans n_clusters=4 0.5392077301035408 0.5284496560928023
# KMeans n_clusters=5 0.5869979917894966 0.6085165109351085
# KMeans n_clusters=6 0.6004110762092915 0.6351747693916923
# KMeans n_clusters=7 0.6629022884113003 0.6769496925397007
# KMeans n_clusters=8 0.6850138217436816 0.6707592247559359
# KMeans n_clusters=9 0.721711034171263 0.6895526997247158
# KMeans n_clusters=10 0.70939501459123 0.7174016291385115
# KMeans n_clusters=11 0.7318720358978067 0.712536472401429
# KMeans n_clusters=12 0.7488174892202678 0.7504346607089696
# KMeans n_clusters=13 0.7608984519177641 0.7638996644142116
# KMeans n_clusters=14 0.7733318819588628 0.7689078980176817
# KMeans n_clusters=15 0.7893590906026662 0.7762400316977094
# KMeans n_clusters=16 0.7812724937753966 0.798175801184592
# KMeans n_clusters=17 0.8062765537671923 0.8003521967521314
# KMeans n_clusters=18 0.8179075324553126 0.8023253020504285
# KMeans n_clusters=19 0.8226758308202806 0.8099086177134082

# %% [markdown]
# ## Comparison of partitions

# %% [markdown]
# ### Comparison of NCut-values
# The NCut-values of the clusterings are slightly higher for the first graph.

# %%
kmeans_ncut_results = [list(res) for res in kmeans_ncut_results]
result_diffs = np.asarray([res[1] - res[2] for res in kmeans_ncut_results])
describe(result_diffs)
# Out:
# DescribeResult(nobs=18, minmax=(-0.27045291854712517, 0.28942501001892573), mean=0.03965918484325569, variance=0.02685434201294115, skewness=-0.08877684711377885, kurtosis=-0.86674060463961)

# %% [markdown]
# ### NMI scores
# Compares how similar clusterings on G1 and G2 are by calculating the NMIs between them.

# %%
descriptions = [res[0] for res in kmeans_ncut_results]

kmeans_nmis = [normalized_mutual_info_score(res[3], res[4]) for res in kmeans_ncut_results]
for res, nmi in zip(descriptions, kmeans_nmis):
    print(f"{res} NMI: {nmi}")
# Out:
# KMeans n_clusters=2 NMI: 0.6780944524398714
# KMeans n_clusters=3 NMI: 0.7770279988463307
# KMeans n_clusters=4 NMI: 0.646327180797945
# KMeans n_clusters=5 NMI: 0.613913961669145
# KMeans n_clusters=6 NMI: 0.6004459230231852
# KMeans n_clusters=7 NMI: 0.5800435164933219
# KMeans n_clusters=8 NMI: 0.5806522567931678
# KMeans n_clusters=9 NMI: 0.5767734672748275
# KMeans n_clusters=10 NMI: 0.6360986251368707
# KMeans n_clusters=11 NMI: 0.6440227834261241
# KMeans n_clusters=12 NMI: 0.6320583891720516
# KMeans n_clusters=13 NMI: 0.6635325641451542
# KMeans n_clusters=14 NMI: 0.6877544544770605
# KMeans n_clusters=15 NMI: 0.6708953486375112
# KMeans n_clusters=16 NMI: 0.697820327998712
# KMeans n_clusters=17 NMI: 0.7194733713770838
# KMeans n_clusters=18 NMI: 0.7007599223305763
# KMeans n_clusters=19 NMI: 0.695711972427002

# %% [markdown]
# ### Comparison by attributes in clinical.csv
# In this section we investigate whether the attributes in clinical.csv (such as the age) have an influence on the NCut values of the partitions. To do that, we interpret the column values of clinical.csv as cluster labels, and compute the NCut valus of the graph layers (i.e. the patients) individually. Afterwards, we group the NCut values by cluster labels and compare descriptive statistics between the groups.

# %%
comparison_attributes = [
    ['sex', clinical_csv['SEX']],
    ['age over 50', clinical_csv['AGE'] > 50],
    ['BMI over 25', clinical_csv['BMI'] > 25],
    ['MS type', clinical_csv['MS_TYPE']],
    ['therapy', clinical_csv['THERAPY']]
]

# %%
# takes a while to run

individual_ncuts = []

for res in kmeans_ncut_results:
    
    G1_ncuts = []
    G1_partition = res[3]
    for patient in G1s:
        G1_ncuts.append(ncut_by_k_partition(patient, G1_partition))

    G2_ncuts = []
    G2_partition = res[4]
    for patient in G2s:
        G2_ncuts.append(ncut_by_k_partition(patient, G2_partition))
        
    individual_ncuts.append([res[0], G1_ncuts, G2_ncuts])

# %%
attribute_statistics = []

for part_description, G1_ncuts, G2_ncuts in individual_ncuts:
    for comp_description, labels in comparison_attributes:
        
        label_ncuts_g1 = {}
        label_ncuts_g2 = {}
        
        for label in np.unique(labels):
            indices = np.where(labels == label)[0]
            
            # note: if desired, more descriptive statistics could be saved here
            stats = describe(np.asarray(G1_ncuts)[indices])
            label_ncuts_g1[label] = {'mean': stats.mean, 'variance': stats.variance}
            
            stats = describe(np.asarray(G2_ncuts)[indices])
            label_ncuts_g2[label] = {'mean': stats.mean, 'variance': stats.variance}
            
        attribute_statistics.append({'partition_name' : part_description, 'attribute_name' : comp_description,
                                    'G1' : label_ncuts_g1, 'G2' : label_ncuts_g2})

# %%
for entry in attribute_statistics:
    
    print("Partition:", entry['partition_name'])
    print("Attribute:", entry['attribute_name'], "\n")
    
    for key in entry['G1'].keys():
        print(key)
        print("G1 mean ncut:", entry['G1'][key]['mean'])
        print("G2 mean ncut:", entry['G2'][key]['mean'])
        print()
        
    print("-------------------")
# Out:
# Partition: KMeans n_clusters=2
# Attribute: sex
#
# F
# G1 mean ncut: 0.44666108655689596
# G2 mean ncut: 0.5045774425620273
#
# M
# G1 mean ncut: 0.42536134258475505
# G2 mean ncut: 0.483686714324778
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: age over 50
#
# False
# G1 mean ncut: 0.43628292896835297
# G2 mean ncut: 0.5049785283882371
#
# True
# G1 mean ncut: 0.4413904421973277
# G2 mean ncut: 0.4855726861178785
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 0.4428168093559048
# G2 mean ncut: 0.5086785707632295
#
# True
# G1 mean ncut: 0.43103328756955167
# G2 mean ncut: 0.4756533688755535
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 0.44234057280040023
# G2 mean ncut: 0.45672633228023773
#
# relapsing_remitting
# G1 mean ncut: 0.42996563080729894
# G2 mean ncut: 0.4949442755822466
#
# secondary_progressive
# G1 mean ncut: 0.45184480989019776
# G2 mean ncut: 0.5112848220393547
#
# -------------------
# Partition: KMeans n_clusters=2
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 0.44056838087736216
# G2 mean ncut: 0.5044812888188805
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 0.429631203714525
# G2 mean ncut: 0.5014193051081834
#
# Vojta_reflex_locomotion
# G1 mean ncut: 0.4596093234119202
# G2 mean ncut: 0.4759728212262479
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: sex
#
# F
# G1 mean ncut: 1.340638133876614
# G2 mean ncut: 1.3034914584312203
#
# M
# G1 mean ncut: 1.306766468132667
# G2 mean ncut: 1.2675256745143668
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: age over 50
#
# False
# G1 mean ncut: 1.336347314066446
# G2 mean ncut: 1.2964786546563831
#
# True
# G1 mean ncut: 1.3162858093164187
# G2 mean ncut: 1.2808461622103289
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 1.3326637760780358
# G2 mean ncut: 1.3011414861804809
#
# True
# G1 mean ncut: 1.3190007377054866
# G2 mean ncut: 1.2699499091330597
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 1.3149803623302663
# G2 mean ncut: 1.2436963070802134
#
# relapsing_remitting
# G1 mean ncut: 1.3174360527815105
# G2 mean ncut: 1.2888174644137456
#
# secondary_progressive
# G1 mean ncut: 1.348826587596655
# G2 mean ncut: 1.3050151421618472
#
# -------------------
# Partition: KMeans n_clusters=3
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 1.3530941173934796
# G2 mean ncut: 1.2779045527693749
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 1.312422904715735
# G2 mean ncut: 1.2999955918690738
#
# Vojta_reflex_locomotion
# G1 mean ncut: 1.3420490333873727
# G2 mean ncut: 1.2745896281719384
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: sex
#
# F
# G1 mean ncut: 2.1402134007332907
# G2 mean ncut: 2.129464282022319
#
# M
# G1 mean ncut: 2.045474198219127
# G2 mean ncut: 2.075213092000809
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: age over 50
#
# False
# G1 mean ncut: 2.157665562844567
# G2 mean ncut: 2.110171659476553
#
# True
# G1 mean ncut: 2.0335835865175533
# G2 mean ncut: 2.1067016587939067
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 2.1138464633670044
# G2 mean ncut: 2.1063318938349656
#
# True
# G1 mean ncut: 2.086710762646613
# G2 mean ncut: 2.112703072050714
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 2.05391465724092
# G2 mean ncut: 2.0412604054408914
#
# relapsing_remitting
# G1 mean ncut: 2.144987801933066
# G2 mean ncut: 2.1090577374091843
#
# secondary_progressive
# G1 mean ncut: 2.0490364588500944
# G2 mean ncut: 2.128227702314338
#
# -------------------
# Partition: KMeans n_clusters=4
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 2.152238665943304
# G2 mean ncut: 2.08885009878898
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 2.077537392899354
# G2 mean ncut: 2.1276278098100163
#
# Vojta_reflex_locomotion
# G1 mean ncut: 2.1244944900254366
# G2 mean ncut: 2.0788986717728544
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: sex
#
# F
# G1 mean ncut: 2.903925739094991
# G2 mean ncut: 2.9996949262073045
#
# M
# G1 mean ncut: 2.793445420077849
# G2 mean ncut: 2.939453068404229
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: age over 50
#
# False
# G1 mean ncut: 2.9087380677397
# G2 mean ncut: 2.9408044799087665
#
# True
# G1 mean ncut: 2.799900104044438
# G2 mean ncut: 3.023414635618058
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 2.8776899889722545
# G2 mean ncut: 2.984809523206909
#
# True
# G1 mean ncut: 2.8337398830617957
# G2 mean ncut: 2.9624259527774996
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 2.807674546380284
# G2 mean ncut: 2.9912068091229993
#
# relapsing_remitting
# G1 mean ncut: 2.9006755076537267
# G2 mean ncut: 2.929735950718917
#
# secondary_progressive
# G1 mean ncut: 2.8112741234898384
# G2 mean ncut: 3.051893483189319
#
# -------------------
# Partition: KMeans n_clusters=5
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 2.9239930323997756
# G2 mean ncut: 3.0184047584261506
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 2.83592958756484
# G2 mean ncut: 3.03935094515875
#
# Vojta_reflex_locomotion
# G1 mean ncut: 2.8662293546079645
# G2 mean ncut: 2.7706876036946224
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: sex
#
# F
# G1 mean ncut: 3.573721277577744
# G2 mean ncut: 3.7486362217434257
#
# M
# G1 mean ncut: 3.4297069279025036
# G2 mean ncut: 3.708759154396172
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: age over 50
#
# False
# G1 mean ncut: 3.592994865596857
# G2 mean ncut: 3.7004978066402376
#
# True
# G1 mean ncut: 3.421120045455422
# G2 mean ncut: 3.7763105896096403
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 3.5399948817807876
# G2 mean ncut: 3.7446679021136737
#
# True
# G1 mean ncut: 3.4814155047483712
# G2 mean ncut: 3.7138009306954145
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 3.520730891481662
# G2 mean ncut: 3.7917202493357838
#
# relapsing_remitting
# G1 mean ncut: 3.55190048207757
# G2 mean ncut: 3.6834966496089585
#
# secondary_progressive
# G1 mean ncut: 3.461097243630337
# G2 mean ncut: 3.8005896586449723
#
# -------------------
# Partition: KMeans n_clusters=6
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 3.5622720503663774
# G2 mean ncut: 3.804503257656945
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 3.4946748130654552
# G2 mean ncut: 3.7761215615670913
#
# Vojta_reflex_locomotion
# G1 mean ncut: 3.5371127933189013
# G2 mean ncut: 3.550332716369023
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: sex
#
# F
# G1 mean ncut: 4.60194857743772
# G2 mean ncut: 4.67434135850095
#
# M
# G1 mean ncut: 4.467559420327789
# G2 mean ncut: 4.625012086235189
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: age over 50
#
# False
# G1 mean ncut: 4.615933684710207
# G2 mean ncut: 4.617203507257434
#
# True
# G1 mean ncut: 4.4647776443303
# G2 mean ncut: 4.705422653891988
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 4.563387992675513
# G2 mean ncut: 4.652241555392491
#
# True
# G1 mean ncut: 4.528055468684787
# G2 mean ncut: 4.660942233774082
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 4.585862954970914
# G2 mean ncut: 4.688075663129836
#
# relapsing_remitting
# G1 mean ncut: 4.57551539324178
# G2 mean ncut: 4.608496660799095
#
# secondary_progressive
# G1 mean ncut: 4.497163146634441
# G2 mean ncut: 4.725428390099812
#
# -------------------
# Partition: KMeans n_clusters=7
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 4.610043424490211
# G2 mean ncut: 4.7102235644386345
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 4.523576492021996
# G2 mean ncut: 4.714545879384498
#
# Vojta_reflex_locomotion
# G1 mean ncut: 4.561061445047246
# G2 mean ncut: 4.446034000859174
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: sex
#
# F
# G1 mean ncut: 5.44047634010343
# G2 mean ncut: 5.224134954033496
#
# M
# G1 mean ncut: 5.275003907994203
# G2 mean ncut: 5.272730671691275
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: age over 50
#
# False
# G1 mean ncut: 5.409554410202301
# G2 mean ncut: 5.216097423550072
#
# True
# G1 mean ncut: 5.33453325080059
# G2 mean ncut: 5.277634090286009
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 5.380455516028246
# G2 mean ncut: 5.236501905840077
#
# True
# G1 mean ncut: 5.37115476630092
# G2 mean ncut: 5.253578469373443
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 5.372575337609791
# G2 mean ncut: 5.402523125804156
#
# relapsing_remitting
# G1 mean ncut: 5.378526060574053
# G2 mean ncut: 5.1881281189695185
#
# secondary_progressive
# G1 mean ncut: 5.375868819125853
# G2 mean ncut: 5.287715197417505
#
# -------------------
# Partition: KMeans n_clusters=8
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 5.447229843047459
# G2 mean ncut: 5.354616676856376
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 5.366694723422026
# G2 mean ncut: 5.2878254113243575
#
# Vojta_reflex_locomotion
# G1 mean ncut: 5.333931223979056
# G2 mean ncut: 5.013055227998279
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: sex
#
# F
# G1 mean ncut: 6.450266456541645
# G2 mean ncut: 6.0085727492898755
#
# M
# G1 mean ncut: 6.305332789252831
# G2 mean ncut: 6.073931013192392
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: age over 50
#
# False
# G1 mean ncut: 6.433862996687666
# G2 mean ncut: 5.991994051211201
#
# True
# G1 mean ncut: 6.343506582979821
# G2 mean ncut: 6.088069510998829
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 6.3816511941259195
# G2 mean ncut: 6.030591764385181
#
# True
# G1 mean ncut: 6.417262166730503
# G2 mean ncut: 6.038868999114251
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 6.420714741554342
# G2 mean ncut: 6.249333799351706
#
# relapsing_remitting
# G1 mean ncut: 6.406206067186136
# G2 mean ncut: 5.953520217187957
#
# secondary_progressive
# G1 mean ncut: 6.367360915560067
# G2 mean ncut: 6.10509574233248
#
# -------------------
# Partition: KMeans n_clusters=9
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 6.474321123788342
# G2 mean ncut: 6.17660678008723
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 6.373276339965257
# G2 mean ncut: 6.0853360855963885
#
# Vojta_reflex_locomotion
# G1 mean ncut: 6.371149452060672
# G2 mean ncut: 5.755406921210703
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: sex
#
# F
# G1 mean ncut: 7.0307668240665935
# G2 mean ncut: 6.990690527645924
#
# M
# G1 mean ncut: 6.864530091103362
# G2 mean ncut: 7.02782387837558
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: age over 50
#
# False
# G1 mean ncut: 6.97780671780167
# G2 mean ncut: 6.940242757963604
#
# True
# G1 mean ncut: 6.952966776176327
# G2 mean ncut: 7.089509421337501
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 6.946658816629998
# G2 mean ncut: 6.994712502528664
#
# True
# G1 mean ncut: 7.002251343359152
# G2 mean ncut: 7.02256471042947
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 7.012894913690455
# G2 mean ncut: 7.19941198878452
#
# relapsing_remitting
# G1 mean ncut: 6.9547235734098765
# G2 mean ncut: 6.937304382304009
#
# secondary_progressive
# G1 mean ncut: 6.974229680388137
# G2 mean ncut: 7.061533889724705
#
# -------------------
# Partition: KMeans n_clusters=10
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 7.020001956705351
# G2 mean ncut: 7.127252161802104
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 6.956564142447394
# G2 mean ncut: 7.069338312029945
#
# Vojta_reflex_locomotion
# G1 mean ncut: 6.941489100420028
# G2 mean ncut: 6.714132154853236
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: sex
#
# F
# G1 mean ncut: 7.9632790252488235
# G2 mean ncut: 7.632407323887327
#
# M
# G1 mean ncut: 7.7863671298307136
# G2 mean ncut: 7.6992703279761825
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: age over 50
#
# False
# G1 mean ncut: 7.897441569466482
# G2 mean ncut: 7.612469562120232
#
# True
# G1 mean ncut: 7.8928751753250985
# G2 mean ncut: 7.717627823661363
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 7.884586423430114
# G2 mean ncut: 7.627903922772025
#
# True
# G1 mean ncut: 7.914249264998574
# G2 mean ncut: 7.7100881573611995
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 7.993717631065628
# G2 mean ncut: 7.862239321256266
#
# relapsing_remitting
# G1 mean ncut: 7.848044328077242
# G2 mean ncut: 7.574237900173673
#
# secondary_progressive
# G1 mean ncut: 7.946597748964649
# G2 mean ncut: 7.739238199692042
#
# -------------------
# Partition: KMeans n_clusters=11
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 7.912892031886299
# G2 mean ncut: 7.7866010809742745
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 7.927160826777661
# G2 mean ncut: 7.71339893487117
#
# Vojta_reflex_locomotion
# G1 mean ncut: 7.795131030411581
# G2 mean ncut: 7.384685437615229
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: sex
#
# F
# G1 mean ncut: 8.90904672381107
# G2 mean ncut: 8.76167080289692
#
# M
# G1 mean ncut: 8.710228619403804
# G2 mean ncut: 8.840543576769363
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: age over 50
#
# False
# G1 mean ncut: 8.850475416951612
# G2 mean ncut: 8.684175070789955
#
# True
# G1 mean ncut: 8.809762417343935
# G2 mean ncut: 8.932783444847034
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 8.811615243128164
# G2 mean ncut: 8.801357663924911
#
# True
# G1 mean ncut: 8.869482172201216
# G2 mean ncut: 8.77557867016976
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 8.914355802954434
# G2 mean ncut: 8.976712385594833
#
# relapsing_remitting
# G1 mean ncut: 8.807261002532943
# G2 mean ncut: 8.684960810993122
#
# secondary_progressive
# G1 mean ncut: 8.85184890617252
# G2 mean ncut: 8.91826900427731
#
# -------------------
# Partition: KMeans n_clusters=12
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 8.888943966174283
# G2 mean ncut: 8.980038079871262
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 8.837084051584496
# G2 mean ncut: 8.861877153643738
#
# Vojta_reflex_locomotion
# G1 mean ncut: 8.765604439473735
# G2 mean ncut: 8.420769516205224
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: sex
#
# F
# G1 mean ncut: 9.693910571339211
# G2 mean ncut: 9.759707227004434
#
# M
# G1 mean ncut: 9.534571416981485
# G2 mean ncut: 9.729943626274151
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: age over 50
#
# False
# G1 mean ncut: 9.66244842416475
# G2 mean ncut: 9.672093623454074
#
# True
# G1 mean ncut: 9.594099511866283
# G2 mean ncut: 9.84794952330888
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 9.626764946705373
# G2 mean ncut: 9.727550655191248
#
# True
# G1 mean ncut: 9.643307534332761
# G2 mean ncut: 9.784133904827364
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 9.655417537436838
# G2 mean ncut: 9.902833089473676
#
# relapsing_remitting
# G1 mean ncut: 9.62397701568757
# G2 mean ncut: 9.700747730047029
#
# secondary_progressive
# G1 mean ncut: 9.641105498606324
# G2 mean ncut: 9.78277247225142
#
# -------------------
# Partition: KMeans n_clusters=13
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 9.624825327026976
# G2 mean ncut: 9.942510542900894
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 9.663253944206678
# G2 mean ncut: 9.77571211497785
#
# Vojta_reflex_locomotion
# G1 mean ncut: 9.56126695198056
# G2 mean ncut: 9.482386295116221
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: sex
#
# F
# G1 mean ncut: 10.592505611378446
# G2 mean ncut: 10.50677377830675
#
# M
# G1 mean ncut: 10.479402565237473
# G2 mean ncut: 10.53888575274775
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: age over 50
#
# False
# G1 mean ncut: 10.59027558556276
# G2 mean ncut: 10.443299275420777
#
# True
# G1 mean ncut: 10.495369104320408
# G2 mean ncut: 10.618185644086216
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 10.53320547680465
# G2 mean ncut: 10.483454823041907
#
# True
# G1 mean ncut: 10.576689022858524
# G2 mean ncut: 10.580623583407068
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 10.615116200167867
# G2 mean ncut: 10.779132053365805
#
# relapsing_remitting
# G1 mean ncut: 10.535330147655987
# G2 mean ncut: 10.461414630518364
#
# secondary_progressive
# G1 mean ncut: 10.552852220007676
# G2 mean ncut: 10.539105617636439
#
# -------------------
# Partition: KMeans n_clusters=14
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 10.598839720151444
# G2 mean ncut: 10.720049582616154
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 10.543107276602896
# G2 mean ncut: 10.53634302560088
#
# Vojta_reflex_locomotion
# G1 mean ncut: 10.515261758076706
# G2 mean ncut: 10.272976512777547
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: sex
#
# F
# G1 mean ncut: 11.654553075343376
# G2 mean ncut: 11.395031346419776
#
# M
# G1 mean ncut: 11.480744878771171
# G2 mean ncut: 11.42131817726472
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: age over 50
#
# False
# G1 mean ncut: 11.624638649859829
# G2 mean ncut: 11.330516494238829
#
# True
# G1 mean ncut: 11.539918534777216
# G2 mean ncut: 11.502650657326928
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 11.588722477292844
# G2 mean ncut: 11.40280586584835
#
# True
# G1 mean ncut: 11.586551902832442
# G2 mean ncut: 11.40908431783559
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 11.553522484054
# G2 mean ncut: 11.667285012803015
#
# relapsing_remitting
# G1 mean ncut: 11.590731722298642
# G2 mean ncut: 11.328646339810481
#
# secondary_progressive
# G1 mean ncut: 11.593479126848203
# G2 mean ncut: 11.456439613212291
#
# -------------------
# Partition: KMeans n_clusters=15
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 11.583575298581728
# G2 mean ncut: 11.596549785592002
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 11.59425352073909
# G2 mean ncut: 11.438838258384367
#
# Vojta_reflex_locomotion
# G1 mean ncut: 11.57573057021156
# G2 mean ncut: 11.12544845360429
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: sex
#
# F
# G1 mean ncut: 12.267445428667427
# G2 mean ncut: 12.553839492206738
#
# M
# G1 mean ncut: 12.11133267871115
# G2 mean ncut: 12.523398068610039
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: age over 50
#
# False
# G1 mean ncut: 12.21562365237546
# G2 mean ncut: 12.4442888359021
#
# True
# G1 mean ncut: 12.197112626549451
# G2 mean ncut: 12.670169091115724
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 12.205301184727928
# G2 mean ncut: 12.488457635425293
#
# True
# G1 mean ncut: 12.211576702335913
# G2 mean ncut: 12.634946665614505
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 12.310255064183115
# G2 mean ncut: 12.799081204847624
#
# relapsing_remitting
# G1 mean ncut: 12.190957283977315
# G2 mean ncut: 12.463147828451268
#
# secondary_progressive
# G1 mean ncut: 12.205102721536196
# G2 mean ncut: 12.599435169662566
#
# -------------------
# Partition: KMeans n_clusters=16
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 12.23591561332095
# G2 mean ncut: 12.74117919800044
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 12.22181564130198
# G2 mean ncut: 12.562690904302817
#
# Vojta_reflex_locomotion
# G1 mean ncut: 12.142115207200895
# G2 mean ncut: 12.28949203610605
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: sex
#
# F
# G1 mean ncut: 13.42493773937436
# G2 mean ncut: 13.37591758192031
#
# M
# G1 mean ncut: 13.275428516587525
# G2 mean ncut: 13.328265098829053
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: age over 50
#
# False
# G1 mean ncut: 13.375822831245692
# G2 mean ncut: 13.281089511083035
#
# True
# G1 mean ncut: 13.356906768308109
# G2 mean ncut: 13.457769401049866
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 13.33489705453574
# G2 mean ncut: 13.286653183458512
#
# True
# G1 mean ncut: 13.4241574620912
# G2 mean ncut: 13.48028303784983
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 13.49820211072516
# G2 mean ncut: 13.704258531361324
#
# relapsing_remitting
# G1 mean ncut: 13.349806000979866
# G2 mean ncut: 13.30234597137765
#
# secondary_progressive
# G1 mean ncut: 13.358746777034899
# G2 mean ncut: 13.347686679455578
#
# -------------------
# Partition: KMeans n_clusters=17
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 13.424556524307654
# G2 mean ncut: 13.57918527471538
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 13.34418593372668
# G2 mean ncut: 13.354452390741661
#
# Vojta_reflex_locomotion
# G1 mean ncut: 13.371999667358287
# G2 mean ncut: 13.144481380584855
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: sex
#
# F
# G1 mean ncut: 14.51101904506078
# G2 mean ncut: 14.12546369134316
#
# M
# G1 mean ncut: 14.348998765321712
# G2 mean ncut: 14.128595631819381
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: age over 50
#
# False
# G1 mean ncut: 14.44813603306475
# G2 mean ncut: 14.041967052805788
#
# True
# G1 mean ncut: 14.449925044055636
# G2 mean ncut: 14.237422166005612
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 14.426977926014297
# G2 mean ncut: 14.108311015355984
#
# True
# G1 mean ncut: 14.486796140050217
# G2 mean ncut: 14.158365342182513
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 14.467376782073137
# G2 mean ncut: 14.459494895771977
#
# relapsing_remitting
# G1 mean ncut: 14.432094833474423
# G2 mean ncut: 14.036477775429582
#
# secondary_progressive
# G1 mean ncut: 14.471959561953941
# G2 mean ncut: 14.180132118615248
#
# -------------------
# Partition: KMeans n_clusters=18
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 14.4933372085845
# G2 mean ncut: 14.385265715605128
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 14.469051137976473
# G2 mean ncut: 14.129759606880151
#
# Vojta_reflex_locomotion
# G1 mean ncut: 14.3518118359115
# G2 mean ncut: 13.859967321134679
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: sex
#
# F
# G1 mean ncut: 15.30416712821566
# G2 mean ncut: 14.996855748339613
#
# M
# G1 mean ncut: 15.23383267477186
# G2 mean ncut: 14.930713178269166
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: age over 50
#
# False
# G1 mean ncut: 15.268341458287823
# G2 mean ncut: 14.868697951666029
#
# True
# G1 mean ncut: 15.288797141613312
# G2 mean ncut: 15.105935978158133
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: BMI over 25
#
# False
# G1 mean ncut: 15.213651571767649
# G2 mean ncut: 14.90582340209773
#
# True
# G1 mean ncut: 15.386980706207334
# G2 mean ncut: 15.084944386774673
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: MS type
#
# primary_progressive
# G1 mean ncut: 15.391454009672543
# G2 mean ncut: 15.31317469876358
#
# relapsing_remitting
# G1 mean ncut: 15.260100779137163
# G2 mean ncut: 14.915754457021935
#
# secondary_progressive
# G1 mean ncut: 15.272009235751664
# G2 mean ncut: 14.963768302871461
#
# -------------------
# Partition: KMeans n_clusters=19
# Attribute: therapy
#
# Functional_electric_stimulation
# G1 mean ncut: 15.344570002121849
# G2 mean ncut: 15.155097594078352
#
# Motor_Program_Activating_Therapy
# G1 mean ncut: 15.254715992092349
# G2 mean ncut: 14.956371350959866
#
# Vojta_reflex_locomotion
# G1 mean ncut: 15.26866011576986
# G2 mean ncut: 14.827474702546342
#
# -------------------

# %% [markdown]
# Comparing the mean NCuts for n_clusters=2 between patients of different ages, it seems that patients under 51 years have a lower average ncut value than those over 50 in graph 1, but a higher average ncut value in graph 2. A higher ncut value means that the partitions are more similar to each other. Based on this result, we can speculate that ???\
# **insert more analysis here**

# %% [markdown]
# # Task 2d

# %%
functions = (
    nx.conductance,
    nx.cut_size,
    nx.edge_expansion,
    nx.mixing_expansion,
)

results = pd.DataFrame()
results['graph'] = ['G1', 'G2']

# only compare k=2 at position 0
# get the two k means clusterings
clustering1, clustering2 = kmeans_ncut_results[0][-2:]

# parameter embedding 1
params1 = (
    G1,
    list(np.where(clustering1==0)[0]),
    list(np.where(clustering1==1)[0]),
)

# parameter embedding 2
params2 = (
    G2,
    list(np.where(clustering2==0)[0]),
    list(np.where(clustering2==1)[0]),
)



for func in functions:

    results[func.__name__] = [func(*params1), func(*params2)]

results
# Out:
#   graph  conductance  cut_size  edge_expansion  mixing_expansion
# 0    G1     0.371081      6842      207.333333          0.064083
# 1    G2     0.387704      9037      220.414634          0.086098

# %%
functions = (
    nx.boundary_expansion,
    nx.node_expansion,
    nx.volume,
)


results = []

for i, n in enumerate(n_clusters):
    df = pd.DataFrame(columns=['graph', 'partition', *[f.__name__ for f in functions]])
    for (G_str, G), cluster in  product({'G1': G1, 'G2': G2}.items(), list(range(n))):
        # a bit hacky
        if G_str == 'G1': clustering = kmeans_ncut_results[i][-2]
        else: clustering = kmeans_ncut_results[i][-1]

        df.loc[len(df.index)] = [
            G_str, cluster,
            *[f(G, np.where(clustering==cluster)[0]) for f in functions]
        ]
    results.append(df)

# %%
results[2]
# Out:
#   graph  partition  boundary_expansion  node_expansion  volume
# 0    G1          0            3.461538        4.461538   15698
# 1    G1          1            0.757576        1.757576   74935
# 2    G1          2            4.272727        5.272727   15587
# 3    G1          3           48.500000       49.500000     548
# 4    G2          0            2.222222        3.222222   34461
# 5    G2          1            3.142857        4.142857   15928
# 6    G2          2            2.052632        3.052632   46400
# 7    G2          3            7.285714        8.285714    8173
